# %% [markdown]
# Eric Phann
# DSBA 6188
# Calmcode 3: lunr.py

# %% [markdown]
# lunr.js is a lightweight search engine that can handle smaller datasets pretty well.
# An example is using the search functionality on a [mkdocs material](https://squidfunk.github.io/mkdocs-material/).
# It has been ported to python as lunr.py

# %% [markdown]
# First, let's grab a dataset.

# %%
# command line for dataset from calmcode... not found
# https://calmcode.io/datasets/%7B'name':%20'lunr.py',%20'link':%20'/shorts/lunr.py.html'%7D returns a 404...
# !curl https://calmcode.io/datasets/clinc.csv

# %%
import pandas as pd
import os

os.chdir(r"C:\Users\Eric\DSBA 6188\Calmcode\data")
df = pd.read_csv("clinc.csv").assign(idx=lambda d: d.index)
df.sample(3)
# Out:
#                                                     text     label    idx
# 12326               how many calories are in a honey bun  calories  12326
# 19534  i need 2000 to go to my chase checking from my...  transfer  19534
# 19171                         i need you to buy a laptop     order  19171

# %% [markdown]
# lunr prefers list of dictionaries, not a dataframe.

# %%
documents = df.to_dict(orient="records")
documents
# Out:
# [{'text': 'how would you say fly in italian', 'label': 'translate', 'idx': 0},
#  {'text': "what's the spanish word for pasta", 'label': 'translate', 'idx': 1},
#  {'text': 'how would they say butter in zambia',
#   'label': 'translate',
#   'idx': 2},
#  {'text': 'how do you say fast in spanish', 'label': 'translate', 'idx': 3},
#  {'text': "what's the word for trees in norway",
#   'label': 'translate',
#   'idx': 4},
#  {'text': 'how does one say wonderful in german',
#   'label': 'translate',
#   'idx': 5},
#  {'text': 'how do they say tacos in mexico', 'label': 'translate', 'idx': 6},
#  {'text': 'how would one say cruiser in china',
#   'label': 'translate',
#   'idx': 7},
#  {'text': "what's the french word you use for potato",
#   'label': 'translate',
#   'idx': 8},
#  {'text': 'what would the word for grass be in finland',
#   'label': 'translate',
#   'idx': 9},
#  {'text': 'how do you say please in french', 'label': 'translate', 'idx': 10},
#  {'text': 'how would i say nice to meet you if i were russian',
#   'label': 'translate',
#   'idx': 11},
#  {'text': 'what is the right way to say excuse me in spanish',
#   'label': 'translate',
#   'idx': 12},
#  {'text': "how do i say i'm sorry in chinese",
#   'label': 'translate',
#   'idx': 13},
#  {'text': 'how would i say thank you if i were mexican',
#   'label': 'translate',
#   'idx': 14},
#  {'text': 'how would i say what is your name if i were french',
#   'label': 'translate',
#   'idx': 15},
#  {'text': 'how would i say i must be going now if i were german',
#   'label': 'translate',
#   'idx': 16},
#  {'text': 'how do i say bathroom in italian', 'label': 'translate', 'idx': 17},
#  {'text': 'how might i say hello if i were scottish',
#   'label': 'translate',
#   'idx': 18},
#  {'text': 'i must know how to say thank you in german',
#   'label': 'translate',
#   'idx': 19},
#  {'text': 'how would i say i love you if i were german',
#   'label': 'translate',
#   'idx': 20},
#  {'text': 'how would i say how are you today if i were mexican',
#   'label': 'translate',
#   'idx': 21},
#  {'text': 'how would i say where is the bathroom if i were korean',
#   'label': 'translate',
#   'idx': 22},
#  {'text': 'how would i say i need directions if i were french',
#   'label': 'translate',
#   'idx': 23},
#  {'text': 'how would i say i am lost if i were japanese',
#   'label': 'translate',
#   'idx': 24},
#  {'text': 'english to spanish for dog', 'label': 'translate', 'idx': 25},
#  {'text': 'what is dog in spanish', 'label': 'translate', 'idx': 26},
#  {'text': 'how do you say dog in spanish', 'label': 'translate', 'idx': 27},
#  {'text': 'dog in spanish', 'label': 'translate', 'idx': 28},
#  {'text': "what's the spanish word for dog", 'label': 'translate', 'idx': 29},
#  {'text': 'can you please provide me with assistance in moving money from one account to another',
#   'label': 'transfer',
#   'idx': 30},
#  {'text': 'i would like help moving money between accounts',
#   'label': 'transfer',
#   'idx': 31},
#  {'text': 'can you assist me in moving money from one account to another',
#   'label': 'transfer',
#   'idx': 32},
#  {'text': 'i would like help moving money from one account to another',
#   'label': 'transfer',
#   'idx': 33},
#  {'text': 'i would like assistance moving money from one account to another',
#   'label': 'transfer',
#   'idx': 34},
#  {'text': 'can i move some money around', 'label': 'transfer', 'idx': 35},
#  {'text': 'can i make a transfer between my accounts',
#   'label': 'transfer',
#   'idx': 36},
#  {'text': 'i need to make a transfer of my money',
#   'label': 'transfer',
#   'idx': 37},
#  {'text': 'can i move some money between my two accounts',
#   'label': 'transfer',
#   'idx': 38},
#  {'text': 'i would like to distribute some money between my accounts',
#   'label': 'transfer',
#   'idx': 39},
#  {'text': 'i would like to transfer $100 from my checking to saving account',
#   'label': 'transfer',
#   'idx': 40},
#  {'text': 'help me transfer $100 from my checking to saving account',
#   'label': 'transfer',
#   'idx': 41},
#  {'text': 'transfer $100 from my checking to saving account',
#   'label': 'transfer',
#   'idx': 42},
#  {'text': 'can you please help me move $100 from my checking to saving account',
#   'label': 'transfer',
#   'idx': 43},
#  {'text': 'please move $100 from my checking to saving account',
#   'label': 'transfer',
#   'idx': 44},
#  {'text': 'transfer seventeen dollars from rbs to woodforest account, please',
#   'label': 'transfer',
#   'idx': 45},
#  {'text': 'send twelve dollars between cabelas and bank of london accounts, please',
#   'label': 'transfer',
#   'idx': 46},
#  {'text': 'transfer ninety dollars between glacier checking and farmers accounts, please',
#   'label': 'transfer',
#   'idx': 47},
#  {'text': 'transfer seventy dollars between national and citizens accounts',
#   'label': 'transfer',
#   'idx': 48},
#  {'text': 'transfer four and sixty seven dollars from bank of oklahoma checking to security bank account',
#   'label': 'transfer',
#   'idx': 49},
#  {'text': 'how much money can i transfer today',
#   'label': 'transfer',
#   'idx': 50},
#  {'text': 'add funds to the retirement account from the pnc account only',
#   'label': 'transfer',
#   'idx': 51},
#  {'text': 'would you move 100 dollars from the checking and put it into savings',
#   'label': 'transfer',
#   'idx': 52},
#  {'text': 'repeat what the weather will be like',
#   'label': 'transfer',
#   'idx': 53},
#  {'text': 'i would like to put 100 dollars from the checking into the savings account now',
#   'label': 'transfer',
#   'idx': 54},
#  {'text': 'please transfer $5000 to money market from checking account',
#   'label': 'transfer',
#   'idx': 55},
#  {'text': 'i need $360 transfered from savings to checking account',
#   'label': 'transfer',
#   'idx': 56},
#  {'text': 'make an immediate transfer of ten thousand from money market to checking',
#   'label': 'transfer',
#   'idx': 57},
#  {'text': "i'd like to transfer $400 from household to savings account",
#   'label': 'transfer',
#   'idx': 58},
#  {'text': 'transer $800 from my checking to savings account',
#   'label': 'transfer',
#   'idx': 59},
#  {'text': 'set a 4 minute timer', 'label': 'timer', 'idx': 60},
#  {'text': 'set a 2 minute timer', 'label': 'timer', 'idx': 61},
#  {'text': 'set a 3 minute timer', 'label': 'timer', 'idx': 62},
#  {'text': 'set a 5 minute timer', 'label': 'timer', 'idx': 63},
#  {'text': 'set a 1 minute timer', 'label': 'timer', 'idx': 64},
#  {'text': 'who set up the numbers for it', 'label': 'timer', 'idx': 65},
#  {'text': 'start the timer', 'label': 'timer', 'idx': 66},
#  {'text': 'start a timer please', 'label': 'timer', 'idx': 67},
#  {'text': 'i need to start a timer', 'label': 'timer', 'idx': 68},
#  {'text': 'i need a timer to be set', 'label': 'timer', 'idx': 69},
#  {'text': 'could you set a timer', 'label': 'timer', 'idx': 70},
#  {'text': 'set a timer', 'label': 'timer', 'idx': 71},
#  {'text': 'i need to have a timer for 10 minutes',
#   'label': 'timer',
#   'idx': 72},
#  {'text': 'make a 10 minute timer', 'label': 'timer', 'idx': 73},
#  {'text': 'give me a 10 minute timer', 'label': 'timer', 'idx': 74},
#  {'text': 'will you create a timer for me', 'label': 'timer', 'idx': 75},
#  {'text': 'please begin a timer', 'label': 'timer', 'idx': 76},
#  {'text': 'is it possible to set a timer', 'label': 'timer', 'idx': 77},
#  {'text': 'i want a timer set for 10 minutes', 'label': 'timer', 'idx': 78},
#  {'text': 'set a timer for 10 minutes', 'label': 'timer', 'idx': 79},
#  {'text': 'can i get a timer set', 'label': 'timer', 'idx': 80},
#  {'text': 'i need to use a timer', 'label': 'timer', 'idx': 81},
#  {'text': 'set a timer to go off in 1 hour', 'label': 'timer', 'idx': 82},
#  {'text': 'i need a timer for 45 minutes', 'label': 'timer', 'idx': 83},
#  {'text': 'in 15 minutes the timer should go off',
#   'label': 'timer',
#   'idx': 84},
#  {'text': 'start the timer now', 'label': 'timer', 'idx': 85},
#  {'text': 'set a timer for 30 minutes', 'label': 'timer', 'idx': 86},
#  {'text': 'set a timer for 5 minutes from now', 'label': 'timer', 'idx': 87},
#  {'text': "let me know when it's been 5 minutes", 'label': 'timer', 'idx': 88},
#  {'text': 'can you set the timer to 20 minutes', 'label': 'timer', 'idx': 89},
#  {'text': 'define antebellum', 'label': 'definition', 'idx': 90},
#  {'text': 'define discontent', 'label': 'definition', 'idx': 91},
#  {'text': 'what is the meaning of incandescent',
#   'label': 'definition',
#   'idx': 92},
#  {'text': 'what does confrontation mean', 'label': 'definition', 'idx': 93},
#  {'text': 'what does serendipity mean', 'label': 'definition', 'idx': 94},
#  {'text': "what's the definition of luminescent",
#   'label': 'definition',
#   'idx': 95},
#  {'text': 'what is the definiton of auspicious',
#   'label': 'definition',
#   'idx': 96},
#  {'text': 'what does circuitous mean', 'label': 'definition', 'idx': 97},
#  {'text': "what's the definition of unencumbered",
#   'label': 'definition',
#   'idx': 98},
#  {'text': 'what does adulation mean', 'label': 'definition', 'idx': 99},
#  {'text': 'what does assiduous mean', 'label': 'definition', 'idx': 100},
#  {'text': 'what does amicable mean', 'label': 'definition', 'idx': 101},
#  {'text': "what's the definition of remunerative",
#   'label': 'definition',
#   'idx': 102},
#  {'text': 'what does anachronistic mean', 'label': 'definition', 'idx': 103},
#  {'text': "what's the definition of idiosyncratic",
#   'label': 'definition',
#   'idx': 104},
#  {'text': 'what does yolo mean', 'label': 'definition', 'idx': 105},
#  {'text': 'can you tell me the meaning of fluctuate',
#   'label': 'definition',
#   'idx': 106},
#  {'text': 'what does the word polynomial mean',
#   'label': 'definition',
#   'idx': 107},
#  {'text': 'what does ferrari mean', 'label': 'definition', 'idx': 108},
#  {'text': 'what is the meaning of the word girn',
#   'label': 'definition',
#   'idx': 109},
#  {'text': 'what does mature mean', 'label': 'definition', 'idx': 110},
#  {'text': "i'd like to know what bitcoin means",
#   'label': 'definition',
#   'idx': 111},
#  {'text': "i heard some woman say she was going to yerd me, what's that mean",
#   'label': 'definition',
#   'idx': 112},
#  {'text': 'can you tell me what obsolescence means',
#   'label': 'definition',
#   'idx': 113},
#  {'text': 'please explain the word catastrophic to me',
#   'label': 'definition',
#   'idx': 114},
#  {'text': "what's the meaning of naff", 'label': 'definition', 'idx': 115},
#  {'text': 'can you tell me what dendrofilous means',
#   'label': 'definition',
#   'idx': 116},
#  {'text': 'what does peer-to-peer actually mean',
#   'label': 'definition',
#   'idx': 117},
#  {'text': 'define epicurean', 'label': 'definition', 'idx': 118},
#  {'text': 'what does epicurean mean', 'label': 'definition', 'idx': 119},
#  {'text': 'would you let me know what the meaning is life is',
#   'label': 'meaning_of_life',
#   'idx': 120},
#  {'text': 'would you let me know what is the point of life',
#   'label': 'meaning_of_life',
#   'idx': 121},
#  {'text': 'right now, i need to know the meaning of life',
#   'label': 'meaning_of_life',
#   'idx': 122},
#  {'text': 'define the meaning of life for me',
#   'label': 'meaning_of_life',
#   'idx': 123},
#  {'text': 'i want to know the meaning of life',
#   'label': 'meaning_of_life',
#   'idx': 124},
#  {'text': 'would you explain the meaning of life',
#   'label': 'meaning_of_life',
#   'idx': 125},
#  {'text': 'i need you to tell me the meaning of life',
#   'label': 'meaning_of_life',
#   'idx': 126},
#  {'text': 'i need to know what the meaning of life is now',
#   'label': 'meaning_of_life',
#   'idx': 127},
#  {'text': 'tell me what the meaning of life is',
#   'label': 'meaning_of_life',
#   'idx': 128},
#  {'text': 'i need to know what the point of life is',
#   'label': 'meaning_of_life',
#   'idx': 129},
#  {'text': 'let me know what the point of life is',
#   'label': 'meaning_of_life',
#   'idx': 130},
#  {'text': 'would you provide me with what the point of life is',
#   'label': 'meaning_of_life',
#   'idx': 131},
#  {'text': 'tell me what the point of life is',
#   'label': 'meaning_of_life',
#   'idx': 132},
#  {'text': 'what is the reason humans even exist',
#   'label': 'meaning_of_life',
#   'idx': 133},
#  {'text': 'do you think our lives have purpose or meaning',
#   'label': 'meaning_of_life',
#   'idx': 134},
#  {'text': 'can you tell me about the meaning of life',
#   'label': 'meaning_of_life',
#   'idx': 135},
#  {'text': 'can you tell me what the meaning of life is',
#   'label': 'meaning_of_life',
#   'idx': 136},
#  {'text': 'what do you know about the meaning of life',
#   'label': 'meaning_of_life',
#   'idx': 137},
#  {'text': 'i would like information on the meaning of life',
#   'label': 'meaning_of_life',
#   'idx': 138},
#  {'text': 'what information can you give me on the meaning of life',
#   'label': 'meaning_of_life',
#   'idx': 139},
#  {'text': 'what is the core meaning of life',
#   'label': 'meaning_of_life',
#   'idx': 140},
#  {'text': 'what do you know about lifes meaning',
#   'label': 'meaning_of_life',
#   'idx': 141},
#  {'text': 'is there any consensun regarding lifes true meaning',
#   'label': 'meaning_of_life',
#   'idx': 142},
#  {'text': 'is there a reason beyond biology about why humans are alive',
#   'label': 'meaning_of_life',
#   'idx': 143},
#  {'text': 'do you think being alive has any meaning',
#   'label': 'meaning_of_life',
#   'idx': 144},
#  {'text': 'is there meaning to life', 'label': 'meaning_of_life', 'idx': 145},
#  {'text': 'is there meaning in life', 'label': 'meaning_of_life', 'idx': 146},
#  {'text': 'what is the answer to life',
#   'label': 'meaning_of_life',
#   'idx': 147},
#  {'text': "what's the answer to it all",
#   'label': 'meaning_of_life',
#   'idx': 148},
#  {'text': "what's life mean to you", 'label': 'meaning_of_life', 'idx': 149},
#  {'text': 'i would like to change my insurance policy',
#   'label': 'insurance_change',
#   'idx': 150},
#  {'text': 'can i edit my insurance policy',
#   'label': 'insurance_change',
#   'idx': 151},
#  {'text': 'i am interested in a new insurance plan',
#   'label': 'insurance_change',
#   'idx': 152},
#  {'text': 'i really would like to get a new insurance plan',
#   'label': 'insurance_change',
#   'idx': 153},
#  {'text': 'i am in the market for a new insurance plan',
#   'label': 'insurance_change',
#   'idx': 154},
#  {'text': 'is there a way to alter my insurance policy',
#   'label': 'insurance_change',
#   'idx': 155},
#  {'text': 'how can i change to new insurance plan',
#   'label': 'insurance_change',
#   'idx': 156},
#  {'text': 'help me find a new insurance plan',
#   'label': 'insurance_change',
#   'idx': 157},
#  {'text': 'can i update my insurance policy',
#   'label': 'insurance_change',
#   'idx': 158},
#  {'text': 'who do i contact about updating my insurance',
#   'label': 'insurance_change',
#   'idx': 159},
#  {'text': 'can you help me change my insurance policy',
#   'label': 'insurance_change',
#   'idx': 160},
#  {'text': 'i need to change my insurance policy, do you know how',
#   'label': 'insurance_change',
#   'idx': 161},
#  {'text': 'what are the steps to change my insurance policy',
#   'label': 'insurance_change',
#   'idx': 162},
#  {'text': 'do you know how i can change my insurance policy',
#   'label': 'insurance_change',
#   'idx': 163},
#  {'text': 'how to i change the policy on my insurace',
#   'label': 'insurance_change',
#   'idx': 164},
#  {'text': 'what do i need to do to get new insurance',
#   'label': 'insurance_change',
#   'idx': 165},
#  {'text': 'do you know how i get new insurance',
#   'label': 'insurance_change',
#   'idx': 166},
#  {'text': 'what is the protocol for getting new insurance',
#   'label': 'insurance_change',
#   'idx': 167},
#  {'text': 'let me know the process for new insurance',
#   'label': 'insurance_change',
#   'idx': 168},
#  {'text': 'i want to sign up for a new allstate insurance plan',
#   'label': 'insurance_change',
#   'idx': 169},
#  {'text': 'i need to sign up for a new allstate plan',
#   'label': 'insurance_change',
#   'idx': 170},
#  {'text': 'what is the procedure for signing up for a new allstate plan',
#   'label': 'insurance_change',
#   'idx': 171},
#  {'text': 'how do i sign up for a new allstatedplan',
#   'label': 'insurance_change',
#   'idx': 172},
#  {'text': 'i want to change to a new allstate insurance plan',
#   'label': 'insurance_change',
#   'idx': 173},
#  {'text': 'i want a new insurance plan',
#   'label': 'insurance_change',
#   'idx': 174},
#  {'text': 'what if i want to switch insurance plans',
#   'label': 'insurance_change',
#   'idx': 175},
#  {'text': 'is there a way to get a new insurance plan',
#   'label': 'insurance_change',
#   'idx': 176},
#  {'text': 'i want to switch to a new insurance plan',
#   'label': 'insurance_change',
#   'idx': 177},
#  {'text': 'how do i switch insurance plans',
#   'label': 'insurance_change',
#   'idx': 178},
#  {'text': 'phone number to state farm to change insurance',
#   'label': 'insurance_change',
#   'idx': 179},
#  {'text': 'can you help me find my phone, please',
#   'label': 'find_phone',
#   'idx': 180},
#  {'text': 'could you help me locate my phone',
#   'label': 'find_phone',
#   'idx': 181},
#  {'text': 'can you help me locate my phone',
#   'label': 'find_phone',
#   'idx': 182},
#  {'text': 'could you help me locate my phone, please',
#   'label': 'find_phone',
#   'idx': 183},
#  {'text': 'can you help me locate my phone, please',
#   'label': 'find_phone',
#   'idx': 184},
#  {'text': 'i cannot locate my phone, can you help me',
#   'label': 'find_phone',
#   'idx': 185},
#  {'text': 'i need help locating my phone', 'label': 'find_phone', 'idx': 186},
#  {'text': 'can you assist me with finding my phone',
#   'label': 'find_phone',
#   'idx': 187},
#  {'text': 'i lost my phone can you help me',
#   'label': 'find_phone',
#   'idx': 188},
#  {'text': 'where the bleep did i put my bleeping phone',
#   'label': 'find_phone',
#   'idx': 189},
#  {'text': 'is my phone somewhere around here',
#   'label': 'find_phone',
#   'idx': 190},
#  {'text': "help, i've lost my cellphone!", 'label': 'find_phone', 'idx': 191},
#  {'text': 'i seem to have lost my phone', 'label': 'find_phone', 'idx': 192},
#  {'text': "do you know my phone's location",
#   'label': 'find_phone',
#   'idx': 193},
#  {'text': 'can you find my phone', 'label': 'find_phone', 'idx': 194},
#  {'text': "where's my phone at", 'label': 'find_phone', 'idx': 195},
#  {'text': "what's my phone's location", 'label': 'find_phone', 'idx': 196},
#  {'text': 'can you help me hunt for my missing cellphone',
#   'label': 'find_phone',
#   'idx': 197},
#  {'text': 'locate my cellphone in this room',
#   'label': 'find_phone',
#   'idx': 198},
#  {'text': 'where did i last put my phone', 'label': 'find_phone', 'idx': 199},
#  {'text': 'find my cellphone for me!', 'label': 'find_phone', 'idx': 200},
#  {'text': 'where did i place my phone', 'label': 'find_phone', 'idx': 201},
#  {'text': "where's my phone", 'label': 'find_phone', 'idx': 202},
#  {'text': "my phone isn't where i left it", 'label': 'find_phone', 'idx': 203},
#  {'text': "i think i've misplaced my phone",
#   'label': 'find_phone',
#   'idx': 204},
#  {'text': "i've lost my phone somewhere", 'label': 'find_phone', 'idx': 205},
#  {'text': 'i think i lost my phone', 'label': 'find_phone', 'idx': 206},
#  {'text': 'would you know where to find my phone',
#   'label': 'find_phone',
#   'idx': 207},
#  {'text': 'please assist me in looking for my phone',
#   'label': 'find_phone',
#   'idx': 208},
#  {'text': 'look for my phone with me', 'label': 'find_phone', 'idx': 209},
#  {'text': 'is there a travel alert in spain',
#   'label': 'travel_alert',
#   'idx': 210},
#  {'text': 'travel alert in cuba', 'label': 'travel_alert', 'idx': 211},
#  {'text': 'alerts for travel in colombia',
#   'label': 'travel_alert',
#   'idx': 212},
#  {'text': 'are there travel alerts in mexico',
#   'label': 'travel_alert',
#   'idx': 213},
#  {'text': 'mexico travel alerts', 'label': 'travel_alert', 'idx': 214},
#  {'text': 'have there been any travel alerts for the us',
#   'label': 'travel_alert',
#   'idx': 215},
#  {'text': 'are there any travel advisories for the us',
#   'label': 'travel_alert',
#   'idx': 216},
#  {'text': 'what are the travel alerts for the us',
#   'label': 'travel_alert',
#   'idx': 217},
#  {'text': 'are there travel alerts for the us',
#   'label': 'travel_alert',
#   'idx': 218},
#  {'text': 'what travel alerts are in effect for the us',
#   'label': 'travel_alert',
#   'idx': 219},
#  {'text': 'i want to know if i will be safe if i travel to europe',
#   'label': 'travel_alert',
#   'idx': 220},
#  {'text': 'would i be safe if i traveled to japan',
#   'label': 'travel_alert',
#   'idx': 221},
#  {'text': 'is it safe to go to north korea',
#   'label': 'travel_alert',
#   'idx': 222},
#  {'text': 'will i be safe going to south america',
#   'label': 'travel_alert',
#   'idx': 223},
#  {'text': 'am i safe to go to africa', 'label': 'travel_alert', 'idx': 224},
#  {'text': 'which countries have travel alerts',
#   'label': 'travel_alert',
#   'idx': 225},
#  {'text': 'is it safe in italy', 'label': 'travel_alert', 'idx': 226},
#  {'text': 'what are the travel conditions for haiti',
#   'label': 'travel_alert',
#   'idx': 227},
#  {'text': 'are there any travel bulletins about haiti',
#   'label': 'travel_alert',
#   'idx': 228},
#  {'text': 'note any travel alerts for haiti',
#   'label': 'travel_alert',
#   'idx': 229},
#  {'text': 'find travel alerts for haiti', 'label': 'travel_alert', 'idx': 230},
#  {'text': 'does the state department say anything about traveling to haiti',
#   'label': 'travel_alert',
#   'idx': 231},
#  {'text': 'is there a travel alert for france',
#   'label': 'travel_alert',
#   'idx': 232},
#  {'text': 'is it safe for me to go to turkey',
#   'label': 'travel_alert',
#   'idx': 233},
#  {'text': 'is it safe to go to serbia', 'label': 'travel_alert', 'idx': 234},
#  {'text': 'safety concerns for malaysia', 'label': 'travel_alert', 'idx': 235},
#  {'text': 'is it safe for me to visit malawi',
#   'label': 'travel_alert',
#   'idx': 236},
#  {'text': 'is travel to monterrey safe now',
#   'label': 'travel_alert',
#   'idx': 237},
#  {'text': 'is it safe for people to travel to pakistan',
#   'label': 'travel_alert',
#   'idx': 238},
#  {'text': 'can people safely travel to cambodia',
#   'label': 'travel_alert',
#   'idx': 239},
#  {'text': 'please help me set up a vacation request',
#   'label': 'pto_request',
#   'idx': 240},
#  {'text': 'how does one go about putting in a vacation request',
#   'label': 'pto_request',
#   'idx': 241},
#  {'text': 'how do i put in a vacation request',
#   'label': 'pto_request',
#   'idx': 242},
#  {'text': 'walk me through on how to make a vacation request',
#   'label': 'pto_request',
#   'idx': 243},
#  {'text': 'please put in a vacation request',
#   'label': 'pto_request',
#   'idx': 244},
#  {'text': 'how is a vacation request done',
#   'label': 'pto_request',
#   'idx': 245},
#  {'text': 'how is a vacation request made',
#   'label': 'pto_request',
#   'idx': 246},
#  {'text': 'what is the process of making a vacation request',
#   'label': 'pto_request',
#   'idx': 247},
#  {'text': 'how would one make a vacation request',
#   'label': 'pto_request',
#   'idx': 248},
#  {'text': 'can i put in a pto request for september 1st to september 8th',
#   'label': 'pto_request',
#   'idx': 249},
#  {'text': 'if i want to make a vacation request, how do i do it',
#   'label': 'pto_request',
#   'idx': 250},
#  {'text': 'can i put in a pto request for august 1st to august 10th',
#   'label': 'pto_request',
#   'idx': 251},
#  {'text': 'can i put in a pto request for january 4th to january 9th',
#   'label': 'pto_request',
#   'idx': 252},
#  {'text': 'can i put in a pto request for december 3rd to december 10th',
#   'label': 'pto_request',
#   'idx': 253},
#  {'text': 'can i put in a pto request for december 25th to january 1st',
#   'label': 'pto_request',
#   'idx': 254},
#  {'text': 'can i take pto from the end of the month to the 5th of the next month',
#   'label': 'pto_request',
#   'idx': 255},
#  {'text': 'can you help me plan a vacation',
#   'label': 'pto_request',
#   'idx': 256},
#  {'text': 'it it possible to take pto from the 8th to the 11th',
#   'label': 'pto_request',
#   'idx': 257},
#  {'text': 'is it ok if i use some of my pto on may 24th to may 29th',
#   'label': 'pto_request',
#   'idx': 258},
#  {'text': 'what do i do to set up a vacation',
#   'label': 'pto_request',
#   'idx': 259},
#  {'text': 'i need to use pto on october 5th to october 10th',
#   'label': 'pto_request',
#   'idx': 260},
#  {'text': 'how do i plan a vacation', 'label': 'pto_request', 'idx': 261},
#  {'text': 'can i put in a pto request for monday to wednesday',
#   'label': 'pto_request',
#   'idx': 262},
#  {'text': 'can i purchase a vacation using this',
#   'label': 'pto_request',
#   'idx': 263},
#  {'text': 'how do i get help with a vacation itinerary',
#   'label': 'pto_request',
#   'idx': 264},
#  {'text': 'how do i request a vacation', 'label': 'pto_request', 'idx': 265},
#  {'text': "i'd like to request a vacation",
#   'label': 'pto_request',
#   'idx': 266},
#  {'text': 'i need to request a vacation', 'label': 'pto_request', 'idx': 267},
#  {'text': 'vacation request information', 'label': 'pto_request', 'idx': 268},
#  {'text': 'vacation request please', 'label': 'pto_request', 'idx': 269},
#  {'text': 'how can i increase my credit score',
#   'label': 'improve_credit_score',
#   'idx': 270},
#  {'text': 'how can i raise my credit score',
#   'label': 'improve_credit_score',
#   'idx': 271},
#  {'text': 'how can i contribute to my credit score',
#   'label': 'improve_credit_score',
#   'idx': 272},
#  {'text': 'how is it possible to get a better credit score',
#   'label': 'improve_credit_score',
#   'idx': 273},
#  {'text': 'how can i up my credit score',
#   'label': 'improve_credit_score',
#   'idx': 274},
#  {'text': 'can you explain to me how i might boost my credit score',
#   'label': 'improve_credit_score',
#   'idx': 275},
#  {'text': "my credit score stinks but i don't know how to improve it",
#   'label': 'improve_credit_score',
#   'idx': 276},
#  {'text': 'what preventative measures can i take to avoid a low credit score',
#   'label': 'improve_credit_score',
#   'idx': 277},
#  {'text': 'how can i keep my credit score from falling',
#   'label': 'improve_credit_score',
#   'idx': 278},
#  {'text': 'give me some ideas for boosting my credit score',
#   'label': 'improve_credit_score',
#   'idx': 279},
#  {'text': 'how can i prevent my credit score from dropping',
#   'label': 'improve_credit_score',
#   'idx': 280},
#  {'text': 'what steps can i take to build my credit score',
#   'label': 'improve_credit_score',
#   'idx': 281},
#  {'text': 'give me some tips on building up my credit score',
#   'label': 'improve_credit_score',
#   'idx': 282},
#  {'text': 'how can i rehabilitate my poor credit score',
#   'label': 'improve_credit_score',
#   'idx': 283},
#  {'text': 'give me some ideas of how to avoid my credit score lowering',
#   'label': 'improve_credit_score',
#   'idx': 284},
#  {'text': 'give me tips on improving my credit score',
#   'label': 'improve_credit_score',
#   'idx': 285},
#  {'text': "what steps should i take if i want to ensure my credit score doesn't drop",
#   'label': 'improve_credit_score',
#   'idx': 286},
#  {'text': 'can you tell me some strategies for raising my credit score',
#   'label': 'improve_credit_score',
#   'idx': 287},
#  {'text': 'i want to know how i can build up a good credit score',
#   'label': 'improve_credit_score',
#   'idx': 288},
#  {'text': '"what\'s the method to improve credit score',
#   'label': 'improve_credit_score',
#   'idx': 289},
#  {'text': '"which is the best way to improve the credit score',
#   'label': 'improve_credit_score',
#   'idx': 290},
#  {'text': '"which could be improve the credit score',
#   'label': 'improve_credit_score',
#   'idx': 291},
#  {'text': '"when the credit score improve',
#   'label': 'improve_credit_score',
#   'idx': 292},
#  {'text': '"where is improve the credit score',
#   'label': 'improve_credit_score',
#   'idx': 293},
#  {'text': 'it is damaging to my credit score if i miss one credit card payment',
#   'label': 'improve_credit_score',
#   'idx': 294},
#  {'text': 'i have a revolving store card and defaulted so will my fico score be affected',
#   'label': 'improve_credit_score',
#   'idx': 295},
#  {'text': 'will my fico score decrease if i increase my student loan debt',
#   'label': 'improve_credit_score',
#   'idx': 296},
#  {'text': 'if i lose my job will my credit score go down',
#   'label': 'improve_credit_score',
#   'idx': 297},
#  {'text': 'can i hurt my credit rating if i open several credit cards in a short time frame',
#   'label': 'improve_credit_score',
#   'idx': 298},
#  {'text': 'will only having five late payments really make my credit bad',
#   'label': 'improve_credit_score',
#   'idx': 299},
#  {'text': 'name unusual facts about the circus',
#   'label': 'fun_fact',
#   'idx': 300},
#  {'text': 'i need interesting baseball trivia from the nineteen eighties',
#   'label': 'fun_fact',
#   'idx': 301},
#  {'text': 'tell me a fun fact about cars', 'label': 'fun_fact', 'idx': 302},
#  {'text': 'give me a fun fact about kangaroo',
#   'label': 'fun_fact',
#   'idx': 303},
#  {'text': 'give me a fun fact about koala', 'label': 'fun_fact', 'idx': 304},
#  {'text': 'give me a fun fact about dolphin', 'label': 'fun_fact', 'idx': 305},
#  {'text': 'what is some trivia about frog', 'label': 'fun_fact', 'idx': 306},
#  {'text': 'tell me fun facts of today', 'label': 'fun_fact', 'idx': 307},
#  {'text': 'give me something interesting about stars',
#   'label': 'fun_fact',
#   'idx': 308},
#  {'text': 'what is some trivia question about coffee',
#   'label': 'fun_fact',
#   'idx': 309},
#  {'text': 'tell me some trivia about sweat', 'label': 'fun_fact', 'idx': 310},
#  {'text': 'tell me some trivia about dolphin',
#   'label': 'fun_fact',
#   'idx': 311},
#  {'text': 'what is some trivia about the weather',
#   'label': 'fun_fact',
#   'idx': 312},
#  {'text': 'give me a fun fact about komodo dragon',
#   'label': 'fun_fact',
#   'idx': 313},
#  {'text': 'give me a amusing fact about wolf',
#   'label': 'fun_fact',
#   'idx': 314},
#  {'text': 'what is the interesting trivia about human bodies',
#   'label': 'fun_fact',
#   'idx': 315},
#  {'text': 'i want to learn something about apples',
#   'label': 'fun_fact',
#   'idx': 316},
#  {'text': "tell me today's fun fact", 'label': 'fun_fact', 'idx': 317},
#  {'text': "i want today's fun fact please", 'label': 'fun_fact', 'idx': 318},
#  {'text': "what is today's fun fact", 'label': 'fun_fact', 'idx': 319},
#  {'text': "today's fun fact", 'label': 'fun_fact', 'idx': 320},
#  {'text': 'i want a fun fact about london', 'label': 'fun_fact', 'idx': 321},
#  {'text': 'tell me something interesting about bees',
#   'label': 'fun_fact',
#   'idx': 322},
#  {'text': 'i would you like to learn something interesting about bees',
#   'label': 'fun_fact',
#   'idx': 323},
#  {'text': 'i want to hear cool bee facts', 'label': 'fun_fact', 'idx': 324},
#  {'text': "what's something interesting about bees",
#   'label': 'fun_fact',
#   'idx': 325},
#  {'text': 'i wanna hear something cool about bees',
#   'label': 'fun_fact',
#   'idx': 326},
#  {'text': 'tell me fun facts on science topics',
#   'label': 'fun_fact',
#   'idx': 327},
#  {'text': 'tell me fun science facts', 'label': 'fun_fact', 'idx': 328},
#  {'text': 'i want to know fun facts about koala bears',
#   'label': 'fun_fact',
#   'idx': 329},
#  {'text': 'please speak in tagalog', 'label': 'change_language', 'idx': 330},
#  {'text': 'speak in german', 'label': 'change_language', 'idx': 331},
#  {'text': 'speak to me in dutch', 'label': 'change_language', 'idx': 332},
#  {'text': 'speak in french please', 'label': 'change_language', 'idx': 333},
#  {'text': 'speak spanish please', 'label': 'change_language', 'idx': 334},
#  {'text': 'i am not understanding the language you are responding in; switch it for me',
#   'label': 'change_language',
#   'idx': 335},
#  {'text': "i can't understand the language you are responding in; i need you to switch it",
#   'label': 'change_language',
#   'idx': 336},
#  {'text': "i need you to switch the language you are responding as i don't understand",
#   'label': 'change_language',
#   'idx': 337},
#  {'text': "i don't understand your language; switch the language",
#   'label': 'change_language',
#   'idx': 338},
#  {'text': 'i need you to switch the language you are responding in',
#   'label': 'change_language',
#   'idx': 339},
#  {'text': "i'd like to speak in portuguese",
#   'label': 'change_language',
#   'idx': 340},
#  {'text': 'can we speak in german', 'label': 'change_language', 'idx': 341},
#  {'text': 'i want to use spanish with you',
#   'label': 'change_language',
#   'idx': 342},
#  {'text': "please let's speak in spanish",
#   'label': 'change_language',
#   'idx': 343},
#  {'text': 'please can we speak in dutch',
#   'label': 'change_language',
#   'idx': 344},
#  {'text': 'can you make the default language swedish',
#   'label': 'change_language',
#   'idx': 345},
#  {'text': 'is it possible to talk to you in mandarin',
#   'label': 'change_language',
#   'idx': 346},
#  {'text': 'would you understand me if i speak to you in navajo',
#   'label': 'change_language',
#   'idx': 347},
#  {'text': "i'd like the language to be in spanish",
#   'label': 'change_language',
#   'idx': 348},
#  {'text': "i'd like to use you using russian",
#   'label': 'change_language',
#   'idx': 349},
#  {'text': 'can i speak spanish to you hombre',
#   'label': 'change_language',
#   'idx': 350},
#  {'text': 'i want to start talking to you in swedish',
#   'label': 'change_language',
#   'idx': 351},
#  {'text': 'can i get you to change your language setting to russian',
#   'label': 'change_language',
#   'idx': 352},
#  {'text': 'please make your language setting norwegian',
#   'label': 'change_language',
#   'idx': 353},
#  {'text': 'i am going to speak english now',
#   'label': 'change_language',
#   'idx': 354},
#  {'text': 'do you speak english', 'label': 'change_language', 'idx': 355},
#  {'text': 'i want to talk english', 'label': 'change_language', 'idx': 356},
#  {'text': 'we have to speak in english',
#   'label': 'change_language',
#   'idx': 357},
#  {'text': 'speak in dutch', 'label': 'change_language', 'idx': 358},
#  {'text': 'i want to speak to you in swiss german',
#   'label': 'change_language',
#   'idx': 359},
#  {'text': 'how long until my paycheck shows up',
#   'label': 'payday',
#   'idx': 360},
#  {'text': 'can you tell me the date of my last check',
#   'label': 'payday',
#   'idx': 361},
#  {'text': 'what was the date when i last go paid',
#   'label': 'payday',
#   'idx': 362},
#  {'text': "what's the date on my last pay stub",
#   'label': 'payday',
#   'idx': 363},
#  {'text': 'when can i expect my paycheck', 'label': 'payday', 'idx': 364},
#  {'text': "when is the next time i'll receive a paycheck",
#   'label': 'payday',
#   'idx': 365},
#  {'text': 'when did i last collect my salary', 'label': 'payday', 'idx': 366},
#  {'text': 'when do i next get paid', 'label': 'payday', 'idx': 367},
#  {'text': 'when is my paycheck arriving', 'label': 'payday', 'idx': 368},
#  {'text': 'what day is payday', 'label': 'payday', 'idx': 369},
#  {'text': 'do you know when my next check is coming',
#   'label': 'payday',
#   'idx': 370},
#  {'text': 'when do i get my next paycheck', 'label': 'payday', 'idx': 371},
#  {'text': "when's pay day for me", 'label': 'payday', 'idx': 372},
#  {'text': 'i need to know when i get paid next',
#   'label': 'payday',
#   'idx': 373},
#  {'text': "when's my next pay day", 'label': 'payday', 'idx': 374},
#  {'text': "what day's my pay coming next", 'label': 'payday', 'idx': 375},
#  {'text': 'when do i get paid for my work', 'label': 'payday', 'idx': 376},
#  {'text': 'look up when my payday is supposed to be',
#   'label': 'payday',
#   'idx': 377},
#  {'text': 'when can i expect to be paid', 'label': 'payday', 'idx': 378},
#  {'text': 'look up the date for my next payday',
#   'label': 'payday',
#   'idx': 379},
#  {'text': 'what day will i earn my payment from work',
#   'label': 'payday',
#   'idx': 380},
#  {'text': 'find out when my next upcoming payday will be',
#   'label': 'payday',
#   'idx': 381},
#  {'text': 'when is the next payday i can look forward to',
#   'label': 'payday',
#   'idx': 382},
#  {'text': 'what day can i expect to receive payment on',
#   'label': 'payday',
#   'idx': 383},
#  {'text': 'when will my next paycheck be coming',
#   'label': 'payday',
#   'idx': 384},
#  {'text': 'when will my payment be deposited', 'label': 'payday', 'idx': 385},
#  {'text': 'when do i get my next pay check', 'label': 'payday', 'idx': 386},
#  {'text': 'is it payday', 'label': 'payday', 'idx': 387},
#  {'text': "do you know when i'll receive my next paycheck",
#   'label': 'payday',
#   'idx': 388},
#  {'text': 'what date do i get paid', 'label': 'payday', 'idx': 389},
#  {'text': 'how long does it take for a credit card to be reissued and mailed to me',
#   'label': 'replacement_card_duration',
#   'idx': 390},
#  {'text': 'can credit card companies expedite delivery of reissued credit cards',
#   'label': 'replacement_card_duration',
#   'idx': 391},
#  {'text': 'can you call the help desk line for my credit card company',
#   'label': 'replacement_card_duration',
#   'idx': 392},
#  {'text': 'how can i request a new credit card',
#   'label': 'replacement_card_duration',
#   'idx': 393},
#  {'text': "what's the phone number for my credit card company",
#   'label': 'replacement_card_duration',
#   'idx': 394},
#  {'text': 'i recently lost my credit card and need to know how long it takes to get a new one mailed to me',
#   'label': 'replacement_card_duration',
#   'idx': 395},
#  {'text': 'i need to know the time it takes to get a new credit card sent to someone who lost theirs',
#   'label': 'replacement_card_duration',
#   'idx': 396},
#  {'text': 'i lost my credit card recently  how long does take to get a new one in the mail',
#   'label': 'replacement_card_duration',
#   'idx': 397},
#  {'text': 'what is amount of time it takes to get a new credit card i lost mine recently',
#   'label': 'replacement_card_duration',
#   'idx': 398},
#  {'text': 'what is the time frame for sending a customer who lost their credit card a new one',
#   'label': 'replacement_card_duration',
#   'idx': 399},
#  {'text': 'will i get getting my new card anytime soon',
#   'label': 'replacement_card_duration',
#   'idx': 400},
#  {'text': 'what is the shipping status of my replacement card',
#   'label': 'replacement_card_duration',
#   'idx': 401},
#  {'text': 'how long until i get my replacement card',
#   'label': 'replacement_card_duration',
#   'idx': 402},
#  {'text': 'when is my new card expected to arrive',
#   'label': 'replacement_card_duration',
#   'idx': 403},
#  {'text': 'is my replacement card due to arrive in the mail today',
#   'label': 'replacement_card_duration',
#   'idx': 404},
#  {'text': 'how long before my new card is mailed to me',
#   'label': 'replacement_card_duration',
#   'idx': 405},
#  {'text': 'what is the shipping time for my card',
#   'label': 'replacement_card_duration',
#   'idx': 406},
#  {'text': 'how much time before my new card is mailed to me',
#   'label': 'replacement_card_duration',
#   'idx': 407},
#  {'text': 'how long does it take to get a new credit card',
#   'label': 'replacement_card_duration',
#   'idx': 408},
#  {'text': 'time to order and receive a new credit card',
#   'label': 'replacement_card_duration',
#   'idx': 409},
#  {'text': 'when will i received a replacement card',
#   'label': 'replacement_card_duration',
#   'idx': 410},
#  {'text': 'time to replace my credit card',
#   'label': 'replacement_card_duration',
#   'idx': 411},
#  {'text': 'how long before the replacement card is mailed to me',
#   'label': 'replacement_card_duration',
#   'idx': 412},
#  {'text': 'how much longer before the card is mailed to me',
#   'label': 'replacement_card_duration',
#   'idx': 413},
#  {'text': 'how long will it takes to get a new credit card',
#   'label': 'replacement_card_duration',
#   'idx': 414},
#  {'text': 'what is the shipping wait for my card',
#   'label': 'replacement_card_duration',
#   'idx': 415},
#  {'text': 'when will the replaecment card arrive',
#   'label': 'replacement_card_duration',
#   'idx': 416},
#  {'text': 'let me know the wait on a replacement credit card',
#   'label': 'replacement_card_duration',
#   'idx': 417},
#  {'text': 'let me know when the replacement card will arrive',
#   'label': 'replacement_card_duration',
#   'idx': 418},
#  {'text': 'how soon can i expect a replacement card for my lost card to arrive',
#   'label': 'replacement_card_duration',
#   'idx': 419},
#  {'text': 'i need you to tell me what time it is in new york now',
#   'label': 'time',
#   'idx': 420},
#  {'text': 'what time is it in adelaide, australia right now',
#   'label': 'time',
#   'idx': 421},
#  {'text': 'is it after noon', 'label': 'time', 'idx': 422},
#  {'text': 'is it six o clock yet', 'label': 'time', 'idx': 423},
#  {'text': 'please give me the time in tanzania at this moment',
#   'label': 'time',
#   'idx': 424},
#  {'text': 'can you tell me the current time in jamaica',
#   'label': 'time',
#   'idx': 425},
#  {'text': 'tell me the time in san francisco, please',
#   'label': 'time',
#   'idx': 426},
#  {'text': 'what time is it right now in adelaide, australia',
#   'label': 'time',
#   'idx': 427},
#  {'text': 'what time is it in the eastern timezone',
#   'label': 'time',
#   'idx': 428},
#  {'text': 'what time is it in the mountain timezone',
#   'label': 'time',
#   'idx': 429},
#  {'text': 'what time is it in the greenwich timezone',
#   'label': 'time',
#   'idx': 430},
#  {'text': 'what time is it in the central timezone',
#   'label': 'time',
#   'idx': 431},
#  {'text': 'tell me what the time is in dallas', 'label': 'time', 'idx': 432},
#  {'text': 'what is the current time in dallas', 'label': 'time', 'idx': 433},
#  {'text': 'can you tell me what time it is in dallas',
#   'label': 'time',
#   'idx': 434},
#  {'text': 'what time is it in dallas', 'label': 'time', 'idx': 435},
#  {'text': 'tell time for another city: dallas', 'label': 'time', 'idx': 436},
#  {'text': 'what time is it right now at home', 'label': 'time', 'idx': 437},
#  {'text': 'what’s the time in new york', 'label': 'time', 'idx': 438},
#  {'text': 'tell me the time in california', 'label': 'time', 'idx': 439},
#  {'text': 'tell me the time in las vegas', 'label': 'time', 'idx': 440},
#  {'text': 'what is the time is central time zone',
#   'label': 'time',
#   'idx': 441},
#  {'text': 'what is the time in the usa', 'label': 'time', 'idx': 442},
#  {'text': 'what is the time in est', 'label': 'time', 'idx': 443},
#  {'text': 'whats the exact time', 'label': 'time', 'idx': 444},
#  {'text': 'what is the current time', 'label': 'time', 'idx': 445},
#  {'text': "what's the current time", 'label': 'time', 'idx': 446},
#  {'text': 'what time is it in california', 'label': 'time', 'idx': 447},
#  {'text': 'please give me the time', 'label': 'time', 'idx': 448},
#  {'text': 'the time is what', 'label': 'time', 'idx': 449},
#  {'text': 'how is the status of my credit card application coming along',
#   'label': 'application_status',
#   'idx': 450},
#  {'text': 'what exactly is the status of my application for the credit card',
#   'label': 'application_status',
#   'idx': 451},
#  {'text': 'i need to know the status of my credit card application',
#   'label': 'application_status',
#   'idx': 452},
#  {'text': 'i would like to know the status of my credit card application',
#   'label': 'application_status',
#   'idx': 453},
#  {'text': 'let me know if my application for american saving bank',
#   'label': 'application_status',
#   'idx': 454},
#  {'text': 'check the status of my credit card application for me',
#   'label': 'application_status',
#   'idx': 455},
#  {'text': 'i want to know if my credit card application has been processed',
#   'label': 'application_status',
#   'idx': 456},
#  {'text': 'i want to know the status of my credit card application',
#   'label': 'application_status',
#   'idx': 457},
#  {'text': 'can you check if my credit card application has been processed',
#   'label': 'application_status',
#   'idx': 458},
#  {'text': 'i want to know how is my credit card application going',
#   'label': 'application_status',
#   'idx': 459},
#  {'text': 'can you let me know the status of my discover credit card application status',
#   'label': 'application_status',
#   'idx': 460},
#  {'text': 'can you tell me the status of my credit card application',
#   'label': 'application_status',
#   'idx': 461},
#  {'text': 'has my application for american express gone through yet',
#   'label': 'application_status',
#   'idx': 462},
#  {'text': 'let me know about the status of my credit card application',
#   'label': 'application_status',
#   'idx': 463},
#  {'text': 'can you please tell me about the status of my credit card application',
#   'label': 'application_status',
#   'idx': 464},
#  {'text': 'can you please let me know the status of my capital one application',
#   'label': 'application_status',
#   'idx': 465},
#  {'text': 'let me know the credit card application status',
#   'label': 'application_status',
#   'idx': 466},
#  {'text': 'has my application for discover card gone through yet',
#   'label': 'application_status',
#   'idx': 467},
#  {'text': 'can you tell me the credit card application status',
#   'label': 'application_status',
#   'idx': 468},
#  {'text': 'has my application for the hsbc card been approved yet',
#   'label': 'application_status',
#   'idx': 469},
#  {'text': 'please tell me if my application for the hsbc card has gone through yet',
#   'label': 'application_status',
#   'idx': 470},
#  {'text': 'how far has my application for the hsbc card gone till now',
#   'label': 'application_status',
#   'idx': 471},
#  {'text': "what's the status on my application for the hsbc credit card",
#   'label': 'application_status',
#   'idx': 472},
#  {'text': 'how far has my application for the hsbc card proceeded till now',
#   'label': 'application_status',
#   'idx': 473},
#  {'text': 'did the application for my visa card finish',
#   'label': 'application_status',
#   'idx': 474},
#  {'text': 'has my mastercard application gone through the process',
#   'label': 'application_status',
#   'idx': 475},
#  {'text': 'has my mastercard application gone through yet',
#   'label': 'application_status',
#   'idx': 476},
#  {'text': 'has my application for my visa card gone through',
#   'label': 'application_status',
#   'idx': 477},
#  {'text': 'has my mastercard application been processed',
#   'label': 'application_status',
#   'idx': 478},
#  {'text': 'when will i know if my visa card application was approved',
#   'label': 'application_status',
#   'idx': 479},
#  {'text': "what's the status of by delta flight",
#   'label': 'flight_status',
#   'idx': 480},
#  {'text': "what's the status of my virgin airlines flight",
#   'label': 'flight_status',
#   'idx': 481},
#  {'text': "what's the status of my jetblue flight",
#   'label': 'flight_status',
#   'idx': 482},
#  {'text': "what's the status of my southwest flight",
#   'label': 'flight_status',
#   'idx': 483},
#  {'text': "what's the status of my american airlines flight",
#   'label': 'flight_status',
#   'idx': 484},
#  {'text': "what's the news with my delta flight",
#   'label': 'flight_status',
#   'idx': 485},
#  {'text': 'where is my delta flight', 'label': 'flight_status', 'idx': 486},
#  {'text': 'what can you tell me about flight dl123',
#   'label': 'flight_status',
#   'idx': 487},
#  {'text': 'where is flight dl123', 'label': 'flight_status', 'idx': 488},
#  {'text': 'has flight dl123 left', 'label': 'flight_status', 'idx': 489},
#  {'text': 'is flight dl123 going to arrive on time',
#   'label': 'flight_status',
#   'idx': 490},
#  {'text': 'is my spirit flight running on time',
#   'label': 'flight_status',
#   'idx': 491},
#  {'text': "what's the status for my delta flight this afternoon",
#   'label': 'flight_status',
#   'idx': 492},
#  {'text': 'give me the status on my united airlines flight',
#   'label': 'flight_status',
#   'idx': 493},
#  {'text': "what's up with my american airline flight will it be on time",
#   'label': 'flight_status',
#   'idx': 494},
#  {'text': 'tell me what the status is for my aa flight',
#   'label': 'flight_status',
#   'idx': 495},
#  {'text': 'i need for you to get me the status of my american airlines flight',
#   'label': 'flight_status',
#   'idx': 496},
#  {'text': 'tell me the status of my american airlines flight',
#   'label': 'flight_status',
#   'idx': 497},
#  {'text': 'i need to know the status of my american airlines flight',
#   'label': 'flight_status',
#   'idx': 498},
#  {'text': 'would you let me know the status of my american airlines flight',
#   'label': 'flight_status',
#   'idx': 499},
#  {'text': 'let me know the status of my american airlines flight',
#   'label': 'flight_status',
#   'idx': 500},
#  {'text': 'has flight dl123 landed', 'label': 'flight_status', 'idx': 501},
#  {'text': 'is my flight, dl123 on time', 'label': 'flight_status', 'idx': 502},
#  {'text': 'how far out is flight dl123', 'label': 'flight_status', 'idx': 503},
#  {'text': 'is flight dl123 delayed', 'label': 'flight_status', 'idx': 504},
#  {'text': 'what time is boarding scheduled',
#   'label': 'flight_status',
#   'idx': 505},
#  {'text': 'when is boarding scheduled', 'label': 'flight_status', 'idx': 506},
# ...
#   'label': 'freeze_account',
#   'idx': 816},
#  {'text': 'please stop my account', 'label': 'freeze_account', 'idx': 817},
#  {'text': 'please allow my account to freeze',
#   'label': 'freeze_account',
#   'idx': 818},
#  {'text': 'please put my account on hold',
#   'label': 'freeze_account',
#   'idx': 819},
#  {'text': 'freeze my account at the bank immediately',
#   'label': 'freeze_account',
#   'idx': 820},
#  {'text': 'would you be able to freeze my bank account',
#   'label': 'freeze_account',
#   'idx': 821},
#  {'text': 'my account at the bank needs to be frozen',
#   'label': 'freeze_account',
#   'idx': 822},
#  {'text': 'please block my discover account immediately',
#   'label': 'freeze_account',
#   'idx': 823},
#  {'text': 'please put a block on my citi account immediately',
#   'label': 'freeze_account',
#   'idx': 824},
#  {'text': 'block my american saving bank for now',
#   'label': 'freeze_account',
#   'idx': 825},
#  {'text': 'block my bank of america immdediately',
#   'label': 'freeze_account',
#   'idx': 826},
#  {'text': 'put a block on bank of amerian immediately',
#   'label': 'freeze_account',
#   'idx': 827},
#  {'text': 'my account needs to be frozen',
#   'label': 'freeze_account',
#   'idx': 828},
#  {'text': 'freeze my account for me', 'label': 'freeze_account', 'idx': 829},
#  {'text': 'put a freeze on my account', 'label': 'freeze_account', 'idx': 830},
#  {'text': 'could you please put a stop on my bank account',
#   'label': 'freeze_account',
#   'idx': 831},
#  {'text': 'i need to put a stop on my bank account',
#   'label': 'freeze_account',
#   'idx': 832},
#  {'text': 'are you able to put a stop on my bank account',
#   'label': 'freeze_account',
#   'idx': 833},
#  {'text': 'please put a stop on my bank account',
#   'label': 'freeze_account',
#   'idx': 834},
#  {'text': 'i am hoping you can put a stop on my bank account',
#   'label': 'freeze_account',
#   'idx': 835},
#  {'text': 'please put a freeze on my banking account',
#   'label': 'freeze_account',
#   'idx': 836},
#  {'text': 'i need my bank account frozen',
#   'label': 'freeze_account',
#   'idx': 837},
#  {'text': 'how do i freeze my bank account',
#   'label': 'freeze_account',
#   'idx': 838},
#  {'text': 'would you freeze my bank account',
#   'label': 'freeze_account',
#   'idx': 839},
#  {'text': "i heard i can transfer my 401k, but don't know how, do you",
#   'label': 'rollover_401k',
#   'idx': 840},
#  {'text': 'i need some help with transferring my 401k, can you help',
#   'label': 'rollover_401k',
#   'idx': 841},
#  {'text': 'can you tell me how to transfer my 401k',
#   'label': 'rollover_401k',
#   'idx': 842},
#  {'text': 'i want to transfer my 401k', 'label': 'rollover_401k', 'idx': 843},
#  {'text': 'i wanna transfer my 401k', 'label': 'rollover_401k', 'idx': 844},
#  {'text': 'i have to rollover my 401k', 'label': 'rollover_401k', 'idx': 845},
#  {'text': 'i must rollover my 401k', 'label': 'rollover_401k', 'idx': 846},
#  {'text': 'i want help to transfer my 401k',
#   'label': 'rollover_401k',
#   'idx': 847},
#  {'text': 'help me to transfer my 401k', 'label': 'rollover_401k', 'idx': 848},
#  {'text': 'i will rollover my 401k', 'label': 'rollover_401k', 'idx': 849},
#  {'text': 'i need help to transfer my 401k',
#   'label': 'rollover_401k',
#   'idx': 850},
#  {'text': 'i want to rollover my 401k', 'label': 'rollover_401k', 'idx': 851},
#  {'text': 'how do i transfer my 401k to a new firm',
#   'label': 'rollover_401k',
#   'idx': 852},
#  {'text': 'how do i roll over my 401k', 'label': 'rollover_401k', 'idx': 853},
#  {'text': 'can i move my 401k to an ira',
#   'label': 'rollover_401k',
#   'idx': 854},
#  {'text': 'how do i do a 401(k) rollover',
#   'label': 'rollover_401k',
#   'idx': 855},
#  {'text': 'can 401ks be moved', 'label': 'rollover_401k', 'idx': 856},
#  {'text': 'can i transfer my 401k somewhere',
#   'label': 'rollover_401k',
#   'idx': 857},
#  {'text': 'how do i switch 401k companies',
#   'label': 'rollover_401k',
#   'idx': 858},
#  {'text': 'tell me how to roll over my 401k',
#   'label': 'rollover_401k',
#   'idx': 859},
#  {'text': 'how can i transfer my 401k', 'label': 'rollover_401k', 'idx': 860},
#  {'text': 'what are the steps to rollover my 401k',
#   'label': 'rollover_401k',
#   'idx': 861},
#  {'text': 'my 401k, can i roll it over', 'label': 'rollover_401k', 'idx': 862},
#  {'text': 'i want to rollover my 401k , can i',
#   'label': 'rollover_401k',
#   'idx': 863},
#  {'text': 'help me rollover my 401k', 'label': 'rollover_401k', 'idx': 864},
#  {'text': 'do you know the process to rollover my 401k',
#   'label': 'rollover_401k',
#   'idx': 865},
#  {'text': 'tell me how to rollover my 401k',
#   'label': 'rollover_401k',
#   'idx': 866},
#  {'text': 'my 401k needs to rollover and i need your help',
#   'label': 'rollover_401k',
#   'idx': 867},
#  {'text': 'let me know how to rollover my 401k',
#   'label': 'rollover_401k',
#   'idx': 868},
#  {'text': 'what do i have to do to transfer my 401k',
#   'label': 'rollover_401k',
#   'idx': 869},
#  {'text': 'what company made this ai', 'label': 'who_made_you', 'idx': 870},
#  {'text': 'what is the name of the person who made you',
#   'label': 'who_made_you',
#   'idx': 871},
#  {'text': 'who is the person that brought you to life',
#   'label': 'who_made_you',
#   'idx': 872},
#  {'text': 'who is the one that made you', 'label': 'who_made_you', 'idx': 873},
#  {'text': 'who is your maker', 'label': 'who_made_you', 'idx': 874},
#  {'text': 'which company made you', 'label': 'who_made_you', 'idx': 875},
#  {'text': 'who assembled you', 'label': 'who_made_you', 'idx': 876},
#  {'text': 'i wanna know who programmed you',
#   'label': 'who_made_you',
#   'idx': 877},
#  {'text': 'let me know who programmed you',
#   'label': 'who_made_you',
#   'idx': 878},
#  {'text': 'who made you', 'label': 'who_made_you', 'idx': 879},
#  {'text': 'i wanna know your maker', 'label': 'who_made_you', 'idx': 880},
#  {'text': 'who was your maker', 'label': 'who_made_you', 'idx': 881},
#  {'text': 'who is the one who programmed you',
#   'label': 'who_made_you',
#   'idx': 882},
#  {'text': 'i must know who programmed you',
#   'label': 'who_made_you',
#   'idx': 883},
#  {'text': 'tell me who your maker was', 'label': 'who_made_you', 'idx': 884},
#  {'text': 'what was the company that designed you',
#   'label': 'who_made_you',
#   'idx': 885},
#  {'text': 'do you know what company were you designed by',
#   'label': 'who_made_you',
#   'idx': 886},
#  {'text': 'let me know which company were you designed by',
#   'label': 'who_made_you',
#   'idx': 887},
#  {'text': 'what company were you designed by',
#   'label': 'who_made_you',
#   'idx': 888},
#  {'text': 'can you let me know what company were you designed by',
#   'label': 'who_made_you',
#   'idx': 889},
#  {'text': 'which company were you designed by',
#   'label': 'who_made_you',
#   'idx': 890},
#  {'text': 'tell me who made you please', 'label': 'who_made_you', 'idx': 891},
#  {'text': 'can you tell me who made you', 'label': 'who_made_you', 'idx': 892},
#  {'text': 'whats the name of the person who made you',
#   'label': 'who_made_you',
#   'idx': 893},
#  {'text': 'what company did the design for this',
#   'label': 'who_made_you',
#   'idx': 894},
#  {'text': 'what company did this design', 'label': 'who_made_you', 'idx': 895},
#  {'text': 'what company is responsible for this design',
#   'label': 'who_made_you',
#   'idx': 896},
#  {'text': 'what company designed this', 'label': 'who_made_you', 'idx': 897},
#  {'text': 'for this design, what company did it',
#   'label': 'who_made_you',
#   'idx': 898},
#  {'text': 'name the person or group that programmed you',
#   'label': 'who_made_you',
#   'idx': 899},
#  {'text': 'which way do we go and how long will it take to get to the sears tower in chicago',
#   'label': 'distance',
#   'idx': 900},
#  {'text': 'so, does it take long to get to dodger stadium in anaheim',
#   'label': 'distance',
#   'idx': 901},
#  {'text': 'how many minutes will it take to get to the empire state building in manhattan',
#   'label': 'distance',
#   'idx': 902},
#  {'text': "what's the mileage to get the the taj mahal in atlantic city",
#   'label': 'distance',
#   'idx': 903},
#  {'text': 'does it take long to get to yankee stadium in the bronx',
#   'label': 'distance',
#   'idx': 904},
#  {'text': 'how much time is left until we get there',
#   'label': 'distance',
#   'idx': 905},
#  {'text': "what's the time to destination going via bus to omaha",
#   'label': 'distance',
#   'idx': 906},
#  {'text': 'how far from our destination are we',
#   'label': 'distance',
#   'idx': 907},
#  {'text': 'how many minutes am i from texaco',
#   'label': 'distance',
#   'idx': 908},
#  {'text': 'how long will i be on the bus if i rid it to seattle',
#   'label': 'distance',
#   'idx': 909},
#  {'text': 'is it going to be much longer until i reach the bank',
#   'label': 'distance',
#   'idx': 910},
#  {'text': 'am i close to arriving at the post office',
#   'label': 'distance',
#   'idx': 911},
#  {'text': "what's the estimated travel time to get to dc via bus",
#   'label': 'distance',
#   'idx': 912},
#  {'text': 'when will i arrive at hy-vee', 'label': 'distance', 'idx': 913},
#  {'text': 'how long does it take to get to el paso on a bus',
#   'label': 'distance',
#   'idx': 914},
#  {'text': 'how long will it take me to get to walmart',
#   'label': 'distance',
#   'idx': 915},
#  {'text': "what's the average time to boston when riding a bus",
#   'label': 'distance',
#   'idx': 916},
#  {'text': 'when will the bus get me to vermont',
#   'label': 'distance',
#   'idx': 917},
#  {'text': 'how long will i be on the bus to new orleans',
#   'label': 'distance',
#   'idx': 918},
#  {'text': 'how long is a bus ride to staples',
#   'label': 'distance',
#   'idx': 919},
#  {'text': 'how long does it take to get downtown by bus',
#   'label': 'distance',
#   'idx': 920},
#  {'text': 'what time will i get to the beach taking the bus',
#   'label': 'distance',
#   'idx': 921},
#  {'text': 'how far am i from orlando', 'label': 'distance', 'idx': 922},
#  {'text': 'give me an eta on when i will arrive at my destination',
#   'label': 'distance',
#   'idx': 923},
#  {'text': 'tell me how much longer i will have to drive to reach the destination',
#   'label': 'distance',
#   'idx': 924},
#  {'text': 'when will i get to orlando', 'label': 'distance', 'idx': 925},
#  {'text': 'how much farther is orlando from my location',
#   'label': 'distance',
#   'idx': 926},
#  {'text': 'do i have a ways to go or am i close to getting to penn station',
#   'label': 'distance',
#   'idx': 927},
#  {'text': 'please give me the approximate amount of time i will need to go from jfk international airport to penn station',
#   'label': 'distance',
#   'idx': 928},
#  {'text': 'can you tell me about what time i should be arriving at the airport',
#   'label': 'distance',
#   'idx': 929},
#  {'text': 'how do you refer to me', 'label': 'user_name', 'idx': 930},
#  {'text': 'call my name', 'label': 'user_name', 'idx': 931},
#  {'text': 'what do i go by', 'label': 'user_name', 'idx': 932},
#  {'text': 'say my name', 'label': 'user_name', 'idx': 933},
#  {'text': 'what do you think my name is', 'label': 'user_name', 'idx': 934},
#  {'text': "what do you think i'm called", 'label': 'user_name', 'idx': 935},
#  {'text': 'what do you have for my name', 'label': 'user_name', 'idx': 936},
#  {'text': 'how do you address my name', 'label': 'user_name', 'idx': 937},
#  {'text': "what's your designation", 'label': 'user_name', 'idx': 938},
#  {'text': 'what do you call me', 'label': 'user_name', 'idx': 939},
#  {'text': 'i want to hear my name', 'label': 'user_name', 'idx': 940},
#  {'text': 'my name', 'label': 'user_name', 'idx': 941},
#  {'text': "what's my name", 'label': 'user_name', 'idx': 942},
#  {'text': "what's my name on file", 'label': 'user_name', 'idx': 943},
#  {'text': 'what name do you have for me', 'label': 'user_name', 'idx': 944},
#  {'text': 'what did i tell you to call me', 'label': 'user_name', 'idx': 945},
#  {'text': 'please tell me the name that you have for me',
#   'label': 'user_name',
#   'idx': 946},
#  {'text': 'i need to know the name that you have for me',
#   'label': 'user_name',
#   'idx': 947},
#  {'text': 'can you tell me what name you have for me',
#   'label': 'user_name',
#   'idx': 948},
#  {'text': 'tell me what name you have for me',
#   'label': 'user_name',
#   'idx': 949},
#  {'text': 'i would like to know the name you have for me',
#   'label': 'user_name',
#   'idx': 950},
#  {'text': 'what is the name you have for me',
#   'label': 'user_name',
#   'idx': 951},
#  {'text': 'could you tell me my name', 'label': 'user_name', 'idx': 952},
#  {'text': 'do you have a name for me', 'label': 'user_name', 'idx': 953},
#  {'text': 'can you tell me my name for me', 'label': 'user_name', 'idx': 954},
#  {'text': "what's the name you use for me", 'label': 'user_name', 'idx': 955},
#  {'text': 'you call me what', 'label': 'user_name', 'idx': 956},
#  {'text': 'what do you know me by', 'label': 'user_name', 'idx': 957},
#  {'text': 'you know me by what right now', 'label': 'user_name', 'idx': 958},
#  {'text': "what's the way you refer to me", 'label': 'user_name', 'idx': 959},
#  {'text': "what's the timezone for britain", 'label': 'timezone', 'idx': 960},
#  {'text': 'i need the time zone for la', 'label': 'timezone', 'idx': 961},
#  {'text': 'i would like to know the timezone for britain',
#   'label': 'timezone',
#   'idx': 962},
#  {'text': "i need la's time zone", 'label': 'timezone', 'idx': 963},
#  {'text': "i need to know britain's timezone",
#   'label': 'timezone',
#   'idx': 964},
#  {'text': 'what timezone is britain in', 'label': 'timezone', 'idx': 965},
#  {'text': "can you tell me britain's timezone",
#   'label': 'timezone',
#   'idx': 966},
#  {'text': "what is the la's time zone", 'label': 'timezone', 'idx': 967},
#  {'text': 'can you tell me the time zone for la',
#   'label': 'timezone',
#   'idx': 968},
#  {'text': "what is texas's timezone", 'label': 'timezone', 'idx': 969},
#  {'text': 'tell me the timezone for california',
#   'label': 'timezone',
#   'idx': 970},
#  {'text': 'what timezone would missouri be in',
#   'label': 'timezone',
#   'idx': 971},
#  {'text': 'what timezone do they use in arizona',
#   'label': 'timezone',
#   'idx': 972},
#  {'text': 'is new york in mountain timezone', 'label': 'timezone', 'idx': 973},
#  {'text': 'what is the timezone for la', 'label': 'timezone', 'idx': 974},
#  {'text': 'what is the timezone for new york',
#   'label': 'timezone',
#   'idx': 975},
#  {'text': 'what is the timezone for san francisco',
#   'label': 'timezone',
#   'idx': 976},
#  {'text': 'what is the timezone for paris', 'label': 'timezone', 'idx': 977},
#  {'text': 'what is the timezone for houston', 'label': 'timezone', 'idx': 978},
#  {'text': "denver's timezone is what", 'label': 'timezone', 'idx': 979},
#  {'text': 'does denver reside in the eastern timezones',
#   'label': 'timezone',
#   'idx': 980},
#  {'text': 'which timezone is denver located', 'label': 'timezone', 'idx': 981},
#  {'text': "denver's timezone is a mystery, i wonder where its located",
#   'label': 'timezone',
#   'idx': 982},
#  {'text': 'in which time zone does denver reside',
#   'label': 'timezone',
#   'idx': 983},
#  {'text': "what's the timezone in valencia", 'label': 'timezone', 'idx': 984},
#  {'text': "what's the timezone now in hiram", 'label': 'timezone', 'idx': 985},
#  {'text': 'timezone in salt lake city', 'label': 'timezone', 'idx': 986},
#  {'text': 'timezone currently in mobile', 'label': 'timezone', 'idx': 987},
#  {'text': 'what time is it in phoenix', 'label': 'timezone', 'idx': 988},
#  {'text': 'can you give me the timezone for the country',
#   'label': 'timezone',
#   'idx': 989},
#  {'text': "i don't like this song, can skip it",
#   'label': 'next_song',
#   'idx': 990},
#  {'text': 'can we move onto the next song', 'label': 'next_song', 'idx': 991},
#  {'text': 'skip this song, please', 'label': 'next_song', 'idx': 992},
#  {'text': 'can you swipe to the next song', 'label': 'next_song', 'idx': 993},
#  {'text': 'next song, please!', 'label': 'next_song', 'idx': 994},
#  {'text': 'start the next song', 'label': 'next_song', 'idx': 995},
#  {'text': 'go to the next song and play it', 'label': 'next_song', 'idx': 996},
#  {'text': 'move forward one song', 'label': 'next_song', 'idx': 997},
#  {'text': 'play the next one', 'label': 'next_song', 'idx': 998},
#  {'text': 'skip to next track', 'label': 'next_song', 'idx': 999},
#  ...]

# %% [markdown]
# lunr needs an index passed to it.

# %%
# ! pip install lunr
# Out:
# Collecting lunr
#   Downloading lunr-0.7.0.post1-py3-none-any.whl.metadata (6.8 kB)
# Downloading lunr-0.7.0.post1-py3-none-any.whl (35 kB)
# Installing collected packages: lunr
# Successfully installed lunr-0.7.0.post1

# %%
from lunr import lunr

index = lunr(ref="idx", fields=('text', ), documents=documents)

# %% [markdown]
# Now, can search through the index.

# %%
index.search("spanish")
# Out:
# [{'ref': '4501', 'score': 7.801, 'match_data': <MatchData "spanish">},
#  {'ref': '3', 'score': 7.62, 'match_data': <MatchData "spanish">},
#  {'ref': '26', 'score': 7.62, 'match_data': <MatchData "spanish">},
#  {'ref': '27', 'score': 7.62, 'match_data': <MatchData "spanish">},
#  {'ref': '28', 'score': 7.62, 'match_data': <MatchData "spanish">},
#  {'ref': '4526', 'score': 7.62, 'match_data': <MatchData "spanish">},
#  {'ref': '4529', 'score': 7.62, 'match_data': <MatchData "spanish">},
#  {'ref': '4556', 'score': 7.62, 'match_data': <MatchData "spanish">},
#  {'ref': '4573', 'score': 7.62, 'match_data': <MatchData "spanish">},
#  {'ref': '4575', 'score': 7.62, 'match_data': <MatchData "spanish">},
#  {'ref': '4576', 'score': 7.62, 'match_data': <MatchData "spanish">},
#  {'ref': '4585', 'score': 7.62, 'match_data': <MatchData "spanish">},
#  {'ref': '5638', 'score': 7.62, 'match_data': <MatchData "spanish">},
#  {'ref': '19505', 'score': 7.62, 'match_data': <MatchData "spanish">},
#  {'ref': '19507', 'score': 7.62, 'match_data': <MatchData "spanish">},
#  {'ref': '25', 'score': 6.767, 'match_data': <MatchData "spanish">},
#  {'ref': '334', 'score': 6.767, 'match_data': <MatchData "spanish">},
#  {'ref': '342', 'score': 6.767, 'match_data': <MatchData "spanish">},
#  {'ref': '348', 'score': 6.767, 'match_data': <MatchData "spanish">},
#  {'ref': '350', 'score': 6.767, 'match_data': <MatchData "spanish">},
#  {'ref': '4546', 'score': 6.767, 'match_data': <MatchData "spanish">},
#  {'ref': '4550', 'score': 6.767, 'match_data': <MatchData "spanish">},
#  {'ref': '4559', 'score': 6.767, 'match_data': <MatchData "spanish">},
#  {'ref': '4574', 'score': 6.767, 'match_data': <MatchData "spanish">},
#  {'ref': '4577', 'score': 6.767, 'match_data': <MatchData "spanish">},
#  {'ref': '4579', 'score': 6.767, 'match_data': <MatchData "spanish">},
#  {'ref': '4595', 'score': 6.767, 'match_data': <MatchData "spanish">},
#  {'ref': '4598', 'score': 6.767, 'match_data': <MatchData "spanish">},
#  {'ref': '5619', 'score': 6.767, 'match_data': <MatchData "spanish">},
#  {'ref': '5627', 'score': 6.767, 'match_data': <MatchData "spanish">},
#  {'ref': '5639', 'score': 6.767, 'match_data': <MatchData "spanish">},
#  {'ref': '5640', 'score': 6.767, 'match_data': <MatchData "spanish">},
#  {'ref': '5644', 'score': 6.767, 'match_data': <MatchData "spanish">},
#  {'ref': '5654', 'score': 6.767, 'match_data': <MatchData "spanish">},
#  {'ref': '5672', 'score': 6.767, 'match_data': <MatchData "spanish">},
#  {'ref': '19500', 'score': 6.767, 'match_data': <MatchData "spanish">},
#  {'ref': '1', 'score': 6.085, 'match_data': <MatchData "spanish">},
#  {'ref': '12', 'score': 6.085, 'match_data': <MatchData "spanish">},
#  {'ref': '29', 'score': 6.085, 'match_data': <MatchData "spanish">},
#  {'ref': '343', 'score': 6.085, 'match_data': <MatchData "spanish">},
#  {'ref': '4510', 'score': 6.085, 'match_data': <MatchData "spanish">},
#  {'ref': '4527', 'score': 6.085, 'match_data': <MatchData "spanish">},
#  {'ref': '4543', 'score': 6.085, 'match_data': <MatchData "spanish">},
#  {'ref': '4592', 'score': 6.085, 'match_data': <MatchData "spanish">},
#  {'ref': '5604', 'score': 6.085, 'match_data': <MatchData "spanish">},
#  {'ref': '5618', 'score': 6.085, 'match_data': <MatchData "spanish">},
#  {'ref': '5621', 'score': 6.085, 'match_data': <MatchData "spanish">},
#  {'ref': '5625', 'score': 6.085, 'match_data': <MatchData "spanish">},
#  {'ref': '5647', 'score': 6.085, 'match_data': <MatchData "spanish">},
#  {'ref': '5664', 'score': 6.085, 'match_data': <MatchData "spanish">},
#  {'ref': '18182', 'score': 6.085, 'match_data': <MatchData "spanish">},
#  {'ref': '19517', 'score': 6.085, 'match_data': <MatchData "spanish">},
#  {'ref': '19727', 'score': 6.085, 'match_data': <MatchData "spanish">},
#  {'ref': '5611', 'score': 5.528, 'match_data': <MatchData "spanish">},
#  {'ref': '5692', 'score': 5.528, 'match_data': <MatchData "spanish">},
#  {'ref': '5697', 'score': 5.528, 'match_data': <MatchData "spanish">},
#  {'ref': '19726', 'score': 5.065, 'match_data': <MatchData "spanish">}]

# %% [markdown]
# We can use list comprehension to reformat into records.

# %%
[documents[int(i['ref'])] for i in index.search("spanish")]
# Out:
# [{'text': "can you tell me how to say 'i do not speak much spanish', in spanish",
#   'label': 'translate',
#   'idx': 4501},
#  {'text': 'how do you say fast in spanish', 'label': 'translate', 'idx': 3},
#  {'text': 'what is dog in spanish', 'label': 'translate', 'idx': 26},
#  {'text': 'how do you say dog in spanish', 'label': 'translate', 'idx': 27},
#  {'text': 'dog in spanish', 'label': 'translate', 'idx': 28},
#  {'text': 'how can i say not now in spanish',
#   'label': 'translate',
#   'idx': 4526},
#  {'text': 'how do you say goodbye in spanish',
#   'label': 'translate',
#   'idx': 4529},
#  {'text': 'what is spanish for hello', 'label': 'translate', 'idx': 4556},
#  {'text': 'how do you say thank you in spanish',
#   'label': 'translate',
#   'idx': 4573},
#  {'text': 'how can i say thank you in spanish',
#   'label': 'translate',
#   'idx': 4575},
#  {'text': 'what is thank you in spanish', 'label': 'translate', 'idx': 4576},
#  {'text': 'how do you say cat in spanish', 'label': 'translate', 'idx': 4585},
#  {'text': 'can you talk in spanish', 'label': 'change_language', 'idx': 5638},
#  {'text': 'how do i say dinner in spanish',
#   'label': 'translate',
#   'idx': 19505},
#  {'text': 'how do i say thank you in spanish',
#   'label': 'translate',
#   'idx': 19507},
#  {'text': 'english to spanish for dog', 'label': 'translate', 'idx': 25},
#  {'text': 'speak spanish please', 'label': 'change_language', 'idx': 334},
#  {'text': 'i want to use spanish with you',
#   'label': 'change_language',
#   'idx': 342},
#  {'text': "i'd like the language to be in spanish",
#   'label': 'change_language',
#   'idx': 348},
#  {'text': 'can i speak spanish to you hombre',
#   'label': 'change_language',
#   'idx': 350},
#  {'text': 'what is the word for hello spanish',
#   'label': 'translate',
#   'idx': 4546},
#  {'text': 'tell me how to say hello in spanish',
#   'label': 'translate',
#   'idx': 4550},
#  {'text': 'what is spanish for good morning',
#   'label': 'translate',
#   'idx': 4559},
#  {'text': 'how does one say thank you in spanish',
#   'label': 'translate',
#   'idx': 4574},
#  {'text': 'what is the way to say thank you in spanish',
#   'label': 'translate',
#   'idx': 4577},
#  {'text': 'how do they say "where\'s the bathroom" in spanish',
#   'label': 'translate',
#   'idx': 4579},
#  {'text': 'can you translate hi into spanish for me',
#   'label': 'translate',
#   'idx': 4595},
#  {'text': 'can you translate milk into spanish for me',
#   'label': 'translate',
#   'idx': 4598},
#  {'text': 'fix my language to spanish',
#   'label': 'change_language',
#   'idx': 5619},
#  {'text': 'please respond to me in spanish',
#   'label': 'change_language',
#   'idx': 5627},
#  {'text': 'can i start talking to you in spanish',
#   'label': 'change_language',
#   'idx': 5639},
#  {'text': 'please talk to me in spanish',
#   'label': 'change_language',
#   'idx': 5640},
#  {'text': 'talk to me in spanish from now on',
#   'label': 'change_language',
#   'idx': 5644},
#  {'text': 'is it possible to only talk in spanish',
#   'label': 'change_language',
#   'idx': 5654},
#  {'text': 'start talking in spanish', 'label': 'change_language', 'idx': 5672},
#  {'text': 'in spanish, meet me tomorrow is said how',
#   'label': 'translate',
#   'idx': 19500},
#  {'text': "what's the spanish word for pasta", 'label': 'translate', 'idx': 1},
#  {'text': 'what is the right way to say excuse me in spanish',
#   'label': 'translate',
#   'idx': 12},
#  {'text': "what's the spanish word for dog", 'label': 'translate', 'idx': 29},
#  {'text': "please let's speak in spanish",
#   'label': 'change_language',
#   'idx': 343},
#  {'text': "how would i say, 'i don't know the answer' in spanish",
#   'label': 'translate',
#   'idx': 4510},
#  {'text': 'what do spanish people say for the word cow',
#   'label': 'translate',
#   'idx': 4527},
#  {'text': 'what spanish word means hello', 'label': 'translate', 'idx': 4543},
#  {'text': 'i wanna know a phrase in spanish',
#   'label': 'translate',
#   'idx': 4592},
#  {'text': 'i would like to have language set to spanish, please',
#   'label': 'change_language',
#   'idx': 5604},
#  {'text': 'i need to change language to spanish',
#   'label': 'change_language',
#   'idx': 5618},
#  {'text': 'i need to change my speaking to spanish',
#   'label': 'change_language',
#   'idx': 5621},
#  {'text': 'change your language to spanish please',
#   'label': 'change_language',
#   'idx': 5625},
#  {'text': 'i want to use spanish as my language',
#   'label': 'change_language',
#   'idx': 5647},
#  {'text': 'let’s chat using spanish', 'label': 'change_language', 'idx': 5664},
#  {'text': 'add mia to my spanish playlist',
#   'label': 'update_playlist',
#   'idx': 18182},
#  {'text': 'can you translate this name into spanish for me, please',
#   'label': 'translate',
#   'idx': 19517},
#  {'text': 'change your language setting to spanish',
#   'label': 'change_language',
#   'idx': 19727},
#  {'text': 'i want us to speak to each other in spanish from now on',
#   'label': 'change_language',
#   'idx': 5611},
#  {'text': 'can you start talking to me in spanish from here on out',
#   'label': 'change_language',
#   'idx': 5692},
#  {'text': 'please change your language setting to spanish',
#   'label': 'change_language',
#   'idx': 5697},
#  {'text': 'please change your language setting to spanish now',
#   'label': 'change_language',
#   'idx': 19726}]

# %% [markdown]
# We can also serialize the index, making it into a dictionary

# %%
index.serialize()
# Out:
# {'version': '2.3.9',
#  'fields': ['text'],
#  'fieldVectors': [['text/0', [0, 8.342, 1, 8.161]],
#   ['text/1', [2, 3.398, 3, 6.085, 4, 5.985, 5, 6.726]],
#   ['text/2', [6, 8.649, 7, 12.234]],
#   ['text/3', [3, 7.62, 8, 8.553]],
#   ['text/4', [2, 3.398, 4, 5.985, 9, 8.66, 10, 8.66]],
#   ['text/5', [11, 4.707, 12, 7.772, 13, 7.772]],
#   ['text/6', [14, 8.23, 15, 7.556]],
#   ['text/7', [11, 4.707, 16, 10.864, 17, 7.821]],
#   ['text/8', [2, 3.087, 4, 5.437, 18, 5.291, 19, 3.33, 20, 6.052]],
#   ['text/9', [4, 6.655, 21, 9.216, 22, 9.404]],
#   ['text/10', [18, 7.292, 23, 3.335]],
#   ['text/11', [24, 7.517, 25, 4.839, 26, 8.24]],
#   ['text/12', [3, 6.085, 27, 4.731, 28, 4.838, 29, 9.254]],
#   ['text/13', [30, 4.748, 31, 8.24, 32, 7.443]],
#   ['text/14', [33, 6.622, 34, 8.649]],
#   ['text/15', [18, 7.292, 35, 4.902]],
#   ['text/16', [13, 7.772, 36, 3.877, 37, 4.515]],
#   ['text/17', [1, 8.161, 38, 9.2]],
#   ['text/18', [39, 7.688, 40, 11.588]],
#   ['text/19', [13, 7.772, 33, 5.881, 41, 3.279]],
#   ['text/20', [13, 8.752, 42, 7.973]],
#   ['text/21', [34, 8.649, 43, 5.788]],
#   ['text/22', [38, 9.2, 44, 10.379]],
#   ['text/23', [18, 6.476, 45, 2.739, 46, 5.558]],
#   ['text/24', [47, 5.99, 48, 9.2]],
#   ['text/25', [3, 6.767, 49, 7.189, 50, 6.347]],
#   ['text/26', [3, 7.62, 50, 7.148]],
#   ['text/27', [3, 7.62, 50, 7.148]],
#   ['text/28', [3, 7.62, 50, 7.148]],
#   ['text/29', [2, 3.398, 3, 6.085, 4, 5.985, 50, 5.708]],
#   ['text/30',
#    [11,
#     3.017,
#     23,
#     1.898,
#     51,
#     4.727,
#     52,
#     4.233,
#     53,
#     4.475,
#     54,
#     3.585,
#     55,
#     2.338,
#     56,
#     4.289]],
#   ['text/31', [53, 5.704, 54, 4.569, 55, 2.98, 57, 3.62, 58, 4.651]],
#   ['text/32',
#    [11, 3.523, 52, 4.943, 53, 5.226, 54, 4.186, 55, 2.731, 56, 5.008]],
#   ['text/33',
#    [11, 3.523, 53, 5.226, 54, 4.186, 55, 2.731, 56, 5.008, 57, 3.317]],
#   ['text/34',
#    [11, 3.523, 52, 4.943, 53, 5.226, 54, 4.186, 55, 2.731, 56, 5.008]],
#   ['text/35', [53, 6.981, 54, 5.592, 59, 6.71]],
#   ['text/36', [55, 3.281, 58, 5.12, 60, 3.777, 61, 5.434]],
#   ['text/37', [45, 2.464, 54, 5.029, 60, 3.777, 61, 5.434]],
#   ['text/38', [53, 5.704, 54, 4.569, 55, 2.98, 58, 4.651, 62, 5.395]],
#   ['text/39', [54, 5.029, 55, 3.281, 58, 5.12, 63, 9.254]],
#   ['text/40', [55, 2.98, 61, 4.937, 64, 5.785, 65, 3.41, 66, 4.488]],
#   ['text/41',
#    [55, 2.731, 57, 3.317, 61, 4.523, 64, 5.3, 65, 3.125, 66, 4.112]],
#   ['text/42', [55, 2.98, 61, 4.937, 64, 5.785, 65, 3.41, 66, 4.488]],
#   ['text/43',
#    [23,
#     2.045,
#     53,
#     4.822,
#     55,
#     2.519,
#     57,
#     3.06,
#     64,
#     4.89,
#     65,
#     2.883,
#     66,
#     3.794]],
#   ['text/44',
#    [23, 2.217, 53, 5.226, 55, 2.731, 64, 5.3, 65, 3.125, 66, 4.112]],
#   ['text/45',
#    [23,
#     2.045,
#     55,
#     2.519,
#     61,
#     4.173,
#     67,
#     7.107,
#     68,
#     3.736,
#     69,
#     6.365,
#     70,
#     7.503]],
#   ['text/46',
#    [23,
#     1.771,
#     55,
#     2.182,
#     58,
#     3.405,
#     68,
#     3.235,
#     71,
#     3.496,
#     72,
#     5.416,
#     73,
#     6.498,
#     74,
#     2.496,
#     75,
#     4.594]],
#   ['text/47',
#    [23,
#     1.771,
#     55,
#     2.182,
#     58,
#     3.405,
#     61,
#     3.614,
#     65,
#     2.497,
#     68,
#     3.235,
#     76,
#     6.155,
#     77,
#     6.498,
#     78,
#     6.498]],
#   ['text/48',
#    [55,
#     2.519,
#     58,
#     3.932,
#     61,
#     4.173,
#     68,
#     3.736,
#     79,
#     6.846,
#     80,
#     5.335,
#     81,
#     6.495]],
#   ['text/49',
#    [55,
#     1.924,
#     61,
#     3.187,
#     65,
#     2.202,
#     68,
#     2.853,
#     74,
#     3.467,
#     82,
#     3.889,
#     83,
#     5.079,
#     84,
#     4.474,
#     85,
#     5.228,
#     86,
#     4.636]],
#   ['text/50', [43, 4.622, 54, 5.029, 61, 5.434, 87, 3.73]],
#   ['text/51', [55, 3.951, 88, 3.741, 89, 5.933, 90, 6.778, 91, 6.066]],
#   ['text/52',
#    [53, 5.226, 64, 5.3, 65, 3.125, 66, 4.112, 68, 4.049, 92, 3.617]],
#   ['text/53', [93, 7.275, 94, 6.991]],
#   ['text/54',
#    [37,
#     3.118,
#     55,
#     2.519,
#     64,
#     4.89,
#     65,
#     2.883,
#     66,
#     3.794,
#     68,
#     3.736,
#     92,
#     3.337]],
#   ['text/55',
#    [23,
#     2.045,
#     54,
#     3.862,
#     55,
#     2.519,
#     61,
#     4.173,
#     65,
#     2.883,
#     95,
#     6.254,
#     96,
#     4.985]],
#   ['text/56',
#    [45, 2.051, 55, 2.731, 61, 4.523, 65, 3.125, 66, 4.112, 97, 8.132]],
#   ['text/57',
#    [54,
#     3.585,
#     60,
#     2.692,
#     61,
#     3.874,
#     65,
#     2.676,
#     96,
#     4.627,
#     98,
#     4.843,
#     99,
#     4.749,
#     100,
#     5.563]],
#   ['text/58',
#    [55, 2.731, 61, 4.523, 66, 4.112, 101, 3.897, 102, 6.349, 103, 7.419]],
#   ['text/59', [55, 2.98, 65, 3.41, 66, 4.488, 104, 8.876, 105, 8.407]],
#   ['text/60', [106, 3.662, 107, 5.067, 108, 5.541, 109, 5.219]],
#   ['text/61', [106, 3.662, 108, 5.541, 109, 5.219, 110, 4.859]],
#   ['text/62', [106, 3.662, 108, 5.541, 109, 5.219, 111, 5.416]],
#   ['text/63', [106, 3.662, 108, 5.541, 109, 5.219, 112, 4.963]],
#   ['text/64', [106, 3.662, 108, 5.541, 109, 5.219, 113, 5.784]],
#   ['text/65', [106, 4.072, 114, 4.315, 115, 4.815]],
#   ['text/66', [109, 6.535, 116, 5.966]],
#   ['text/67', [23, 2.961, 109, 5.803, 116, 5.298]],
#   ['text/68', [45, 2.739, 109, 5.803, 116, 5.298]],
#   ['text/69', [45, 2.739, 106, 4.072, 109, 5.803]],
#   ['text/70', [106, 4.586, 109, 6.535]],
#   ['text/71', [106, 4.586, 109, 6.535]],
#   ['text/72', [45, 2.464, 108, 5.541, 109, 5.219, 117, 5.425]],
#   ['text/73', [60, 3.777, 108, 5.541, 109, 5.219, 117, 5.425]],
#   ['text/74', [108, 5.541, 109, 5.219, 117, 5.425, 118, 4.384]],
#   ['text/75', [109, 6.535, 119, 7.327]],
#   ['text/76', [23, 2.961, 109, 5.803, 120, 7.926]],
#   ['text/77', [106, 4.072, 109, 5.803, 121, 6.053]],
#   ['text/78', [106, 3.327, 108, 5.034, 109, 4.741, 117, 4.929, 122, 3.109]],
#   ['text/79', [106, 3.662, 108, 5.541, 109, 5.219, 117, 5.425]],
#   ['text/80', [106, 4.586, 109, 6.535]],
#   ['text/81', [19, 4.076, 45, 2.739, 109, 5.803]],
#   ['text/82', [36, 3.167, 106, 3.327, 109, 4.741, 113, 5.254, 123, 5.997]],
#   ['text/83', [45, 2.464, 108, 5.541, 109, 5.219, 124, 8.144]],
#   ['text/84', [36, 3.486, 108, 5.541, 109, 5.219, 125, 6.795]],
#   ['text/85', [37, 4.515, 109, 5.803, 116, 5.298]],
#   ['text/86', [106, 3.662, 108, 5.541, 109, 5.219, 126, 6.907]],
#   ['text/87', [37, 3.689, 106, 3.327, 108, 5.034, 109, 4.741, 112, 4.509]],
#   ['text/88', [41, 2.949, 108, 5.541, 112, 4.963, 127, 6.216]],
#   ['text/89', [106, 3.662, 108, 5.541, 109, 5.219, 128, 6.415]],
#   ['text/90', [129, 8.925, 130, 12.234]],
#   ['text/91', [129, 8.925, 131, 12.234]],
#   ['text/92', [132, 6.027, 133, 12.234]],
#   ['text/93', [132, 6.027, 134, 12.234]],
#   ['text/94', [132, 6.027, 135, 11.588]],
#   ['text/95', [2, 3.778, 136, 6.891, 137, 10.864]],
#   ['text/96', [138, 12.234, 139, 12.234]],
#   ['text/97', [132, 6.027, 140, 11.162]],
#   ['text/98', [2, 3.778, 136, 6.891, 141, 10.864]],
#   ['text/99', [132, 6.027, 142, 12.234]],
#   ['text/100', [132, 6.027, 143, 12.234]],
#   ['text/101', [132, 6.027, 144, 12.234]],
#   ['text/102', [2, 3.778, 136, 6.891, 145, 10.864]],
#   ['text/103', [132, 6.027, 146, 12.234]],
#   ['text/104', [2, 3.778, 136, 6.891, 147, 10.29]],
#   ['text/105', [132, 6.027, 148, 12.234]],
#   ['text/106', [132, 5.352, 149, 3.068, 150, 10.864]],
#   ['text/107', [4, 6.655, 132, 5.352, 151, 10.864]],
#   ['text/108', [132, 6.027, 152, 12.234]],
#   ['text/109', [4, 6.655, 132, 5.352, 153, 10.864]],
#   ['text/110', [132, 6.027, 154, 12.234]],
#   ['text/111', [41, 2.949, 101, 4.682, 132, 4.813, 155, 9.254]],
#   ['text/112',
#    [2, 2.828, 36, 2.902, 132, 4.006, 156, 6.349, 157, 7.208, 158, 8.132]],
#   ['text/113', [132, 5.352, 149, 3.068, 159, 10.864]],
#   ['text/114', [4, 5.985, 23, 2.663, 160, 6.631, 161, 9.77]],
#   ['text/115', [2, 3.778, 132, 5.352, 162, 10.864]],
#   ['text/116', [132, 5.352, 149, 3.068, 163, 10.864]],
#   ['text/117', [132, 4.813, 164, 13.39, 165, 6.868]],
#   ['text/118', [129, 8.925, 166, 11.588]],
#   ['text/119', [132, 6.027, 166, 11.588]],
#   ['text/120', [41, 3.279, 132, 5.352, 167, 5.723]],
#   ['text/121', [41, 3.279, 167, 5.723, 168, 5.246]],
#   ['text/122',
#    [27, 3.938, 37, 3.379, 41, 2.455, 45, 2.051, 132, 4.006, 167, 4.284]],
#   ['text/123', [129, 7.926, 132, 5.352, 167, 5.723]],
#   ['text/124', [41, 2.949, 122, 3.423, 132, 4.813, 167, 5.147]],
#   ['text/125', [132, 5.352, 160, 7.374, 167, 5.723]],
#   ['text/126', [45, 2.464, 132, 4.813, 149, 2.759, 167, 5.147]],
#   ['text/127', [37, 3.689, 41, 2.679, 45, 2.238, 132, 4.373, 167, 4.676]],
#   ['text/128', [132, 5.352, 149, 3.068, 167, 5.723]],
#   ['text/129', [41, 2.949, 45, 2.464, 167, 5.147, 168, 4.718]],
#   ['text/130', [41, 3.279, 167, 5.723, 168, 5.246]],
#   ['text/131', [51, 7.374, 167, 5.723, 168, 5.246]],
#   ['text/132', [149, 3.068, 167, 5.723, 168, 5.246]],
#   ['text/133', [169, 6.517, 170, 6.237, 171, 7.712, 172, 7.627]],
#   ['text/134', [132, 4.813, 173, 5.305, 174, 6.573, 175, 7.079]],
#   ['text/135', [132, 5.352, 149, 3.068, 167, 5.723]],
#   ['text/136', [132, 5.352, 149, 3.068, 167, 5.723]],
#   ['text/137', [41, 3.279, 132, 5.352, 167, 5.723]],
#   ['text/138', [132, 5.352, 167, 5.723, 176, 5.863]],
#   ['text/139', [118, 4.384, 132, 4.813, 167, 5.147, 176, 5.273]],
#   ['text/140', [132, 5.352, 167, 5.723, 177, 10.864]],
#   ['text/141', [41, 3.279, 132, 5.352, 167, 5.723]],
#   ['text/142', [132, 4.373, 167, 4.676, 178, 8.876, 179, 6.732, 180, 5.595]],
#   ['text/143', [169, 5.921, 170, 5.666, 181, 8.876, 182, 8.876, 183, 7.006]],
#   ['text/144', [132, 4.813, 173, 5.305, 183, 7.712, 184, 6.631]],
#   ['text/145', [132, 6.027, 167, 6.445]],
#   ['text/146', [132, 6.027, 167, 6.445]],
#   ['text/147', [167, 6.445, 185, 7.018]],
#   ['text/148', [2, 4.255, 185, 7.018]],
#   ['text/149', [2, 3.778, 132, 5.352, 167, 5.723]],
#   ['text/150', [186, 3.758, 187, 5.14, 188, 6.57]],
#   ['text/151', [187, 5.14, 188, 6.57, 189, 9.912]],
#   ['text/152', [187, 4.622, 190, 4.902, 191, 3.716, 192, 4.981]],
#   ['text/153', [187, 4.622, 191, 3.716, 192, 4.981, 193, 5.938]],
#   ['text/154', [96, 6.491, 187, 4.622, 191, 3.716, 192, 4.981]],
#   ['text/155', [28, 4.838, 187, 4.622, 188, 5.908, 194, 7.905]],
#   ['text/156', [186, 3.379, 187, 4.622, 191, 3.716, 192, 4.981]],
#   ['text/157', [57, 3.62, 187, 4.2, 191, 3.376, 192, 4.525, 195, 3.423]],
#   ['text/158', [187, 5.14, 188, 6.57, 196, 6.827]],
#   ['text/159', [187, 5.14, 196, 6.827, 197, 7.725]],
#   ['text/160', [57, 3.985, 186, 3.379, 187, 4.622, 188, 5.908]],
#   ['text/161', [41, 2.679, 45, 2.238, 186, 3.07, 187, 4.2, 188, 5.368]],
#   ['text/162', [186, 3.379, 187, 4.622, 188, 5.908, 198, 5.985]],
#   ['text/163', [41, 2.949, 186, 3.379, 187, 4.622, 188, 5.908]],
#   ['text/164', [186, 3.758, 188, 6.57, 199, 10.864]],
#   ['text/165', [45, 2.739, 187, 5.14, 191, 4.132]],
#   ['text/166', [41, 3.279, 187, 5.14, 191, 4.132]],
#   ['text/167', [187, 4.622, 191, 3.716, 200, 8.914, 201, 5.851]],
#   ['text/168', [41, 2.949, 187, 4.622, 191, 3.716, 202, 5.684]],
#   ['text/169',
#    [114,
#     2.98,
#     122,
#     2.628,
#     187,
#     3.55,
#     191,
#     2.854,
#     192,
#     3.825,
#     203,
#     5.368,
#     204,
#     6.651]],
#   ['text/170',
#    [45, 2.051, 114, 3.23, 191, 3.093, 192, 4.146, 203, 5.818, 204, 7.208]],
#   ['text/171',
#    [114, 3.23, 191, 3.093, 192, 4.146, 203, 5.818, 204, 7.208, 205, 6.115]],
#   ['text/172', [114, 3.88, 191, 3.716, 203, 6.989, 206, 9.77]],
#   ['text/173',
#    [122, 2.849, 186, 2.813, 187, 3.847, 191, 3.093, 192, 4.146, 204, 7.208]],
#   ['text/174', [122, 3.423, 187, 4.622, 191, 3.716, 192, 4.981]],
#   ['text/175', [122, 3.423, 187, 4.622, 192, 4.981, 207, 5.288]],
#   ['text/176', [28, 4.838, 187, 4.622, 191, 3.716, 192, 4.981]],
#   ['text/177', [122, 3.109, 187, 4.2, 191, 3.376, 192, 4.525, 207, 4.805]],
#   ['text/178', [187, 5.14, 192, 5.539, 207, 5.881]],
#   ['text/179',
#    [115, 3.604, 186, 2.813, 187, 3.847, 208, 3.509, 209, 4.792, 210, 6.778]],
#   ['text/180', [23, 2.663, 57, 3.985, 195, 3.768, 208, 4.216]],
#   ['text/181', [57, 4.431, 208, 4.688, 211, 4.857]],
#   ['text/182', [57, 4.431, 208, 4.688, 211, 4.857]],
#   ['text/183', [23, 2.663, 57, 3.985, 208, 4.216, 211, 4.368]],
#   ['text/184', [23, 2.663, 57, 3.985, 208, 4.216, 211, 4.368]],
#   ['text/185', [57, 4.431, 208, 4.688, 211, 4.857]],
#   ['text/186', [45, 2.464, 57, 3.985, 208, 4.216, 211, 4.368]],
#   ['text/187', [52, 6.603, 195, 4.19, 208, 4.688]],
#   ['text/188', [47, 5.319, 57, 4.431, 208, 4.688]],
#   ['text/189', [92, 4.346, 208, 4.216, 212, 13.39]],
#   ['text/190', [59, 6.034, 208, 4.216, 213, 7.231, 214, 5.501]],
#   ['text/191', [47, 4.783, 57, 3.985, 215, 5.894, 216, 7.231]],
#   ['text/192', [47, 5.319, 208, 4.688, 217, 7.517]],
#   ['text/193', [41, 3.279, 211, 4.857, 218, 9.404]],
#   ['text/194', [195, 4.718, 208, 5.28]],
#   ['text/195', [208, 5.28, 219, 8.865]],
#   ['text/196', [2, 3.778, 211, 4.857, 218, 9.404]],
#   ['text/197', [57, 3.985, 216, 7.231, 220, 9.77, 221, 6.76]],
#   ['text/198', [211, 4.857, 216, 8.041, 222, 5.89]],
#   ['text/199', [92, 4.832, 208, 4.688, 223, 4.829]],
#   ['text/200', [195, 4.718, 216, 9.055]],
#   ['text/201', [208, 5.28, 224, 6.058]],
#   ['text/202', [208, 5.28, 219, 8.865]],
#   ['text/203', [208, 4.688, 225, 8.17, 226, 6.106]],
#   ['text/204', [173, 5.305, 208, 4.216, 215, 5.894, 227, 8.017]],
#   ['text/205', [47, 4.783, 208, 4.216, 213, 7.231, 215, 5.894]],
#   ['text/206', [47, 5.319, 173, 5.899, 208, 4.688]],
#   ['text/207', [41, 3.279, 195, 4.19, 208, 4.688]],
#   ['text/208', [23, 2.663, 52, 5.938, 208, 4.216, 228, 4.555]],
#   ['text/209', [208, 5.28, 228, 5.703]],
#   ['text/210', [229, 4.655, 230, 5.935, 231, 7.555]],
#   ['text/211', [229, 4.655, 230, 5.935, 232, 7.926]],
#   ['text/212', [229, 4.655, 230, 5.935, 233, 9.63]],
#   ['text/213', [15, 6.71, 229, 4.655, 230, 5.935]],
#   ['text/214', [15, 6.71, 229, 4.655, 230, 5.935]],
#   ['text/215', [229, 5.242, 230, 6.684]],
#   ['text/216', [229, 5.242, 234, 11.162]],
#   ['text/217', [229, 5.242, 230, 6.684]],
#   ['text/218', [229, 5.242, 230, 6.684]],
#   ['text/219', [229, 4.655, 230, 5.935, 235, 10.864]],
#   ['text/220', [41, 2.679, 122, 3.109, 229, 3.803, 236, 5.423, 237, 6.732]],
#   ['text/221', [229, 4.655, 236, 6.638, 238, 7.555]],
#   ['text/222', [36, 3.486, 236, 5.969, 239, 7.804, 240, 7.231]],
#   ['text/223', [36, 3.486, 236, 5.969, 241, 6.662, 242, 5.472]],
#   ['text/224', [36, 3.877, 236, 6.638, 243, 7.479]],
#   ['text/225', [229, 4.655, 230, 5.935, 244, 6.603]],
#   ['text/226', [236, 7.475, 245, 8.649]],
#   ['text/227', [229, 4.655, 246, 9.056, 247, 9.216]],
#   ['text/228', [229, 4.655, 247, 9.216, 248, 10.864]],
#   ['text/229', [229, 4.186, 230, 5.338, 247, 8.288, 249, 7.712]],
#   ['text/230', [195, 3.768, 229, 4.186, 230, 5.338, 247, 8.288]],
#   ['text/231', [209, 5.231, 229, 3.803, 247, 7.53, 250, 7.284, 251, 5.595]],
#   ['text/232', [229, 4.655, 230, 5.935, 252, 6.891]],
#   ['text/233', [36, 3.877, 236, 6.638, 253, 8.315]],
#   ['text/234', [36, 3.877, 236, 6.638, 254, 10.864]],
#   ['text/235', [255, 9.63, 256, 10.29, 257, 9.912]],
#   ['text/236', [236, 6.638, 258, 6.673, 259, 10.29]],
#   ['text/237', [37, 4.06, 229, 4.186, 236, 5.969, 260, 9.77]],
#   ['text/238', [229, 4.186, 236, 5.969, 261, 5.226, 262, 9.254]],
#   ['text/239', [229, 4.186, 236, 5.969, 261, 5.226, 263, 8.66]],
#   ['text/240',
#    [23, 2.217, 57, 3.317, 106, 3.048, 114, 3.23, 264, 3.604, 265, 3.901]],
#   ['text/241', [11, 3.846, 36, 3.167, 92, 3.948, 264, 3.934, 265, 4.258]],
#   ['text/242', [92, 4.832, 264, 4.815, 265, 5.211]],
#   ['text/243', [60, 3.431, 264, 3.934, 265, 4.258, 266, 6.081, 267, 4.954]],
#   ['text/244', [23, 2.663, 92, 4.346, 264, 4.33, 265, 4.686]],
#   ['text/245', [264, 4.815, 265, 5.211, 268, 8.678]],
#   ['text/246', [264, 4.815, 265, 5.211, 269, 6.074]],
#   ['text/247', [60, 3.777, 202, 5.684, 264, 4.33, 265, 4.686]],
#   ['text/248', [11, 4.233, 60, 3.777, 264, 4.33, 265, 4.686]],
#   ['text/249',
#    [92, 3.337, 265, 3.599, 270, 3.881, 271, 9.832, 272, 4.483, 273, 5.116]],
#   ['text/250', [60, 3.777, 122, 3.423, 264, 4.33, 265, 4.686]],
#   ['text/251',
#    [92, 3.337, 265, 3.599, 270, 3.881, 272, 4.483, 274, 8.274, 275, 5.368]],
#   ['text/252',
#    [92, 3.337, 265, 3.599, 270, 3.881, 276, 7.081, 277, 5.191, 278, 5.642]],
#   ['text/253',
#    [92, 3.337, 265, 3.599, 270, 3.881, 275, 5.368, 279, 8.66, 280, 4.822]],
#   ['text/254',
#    [92,
#     3.337,
#     265,
#     3.599,
#     270,
#     3.881,
#     272,
#     4.483,
#     276,
#     4.79,
#     279,
#     5.858,
#     281,
#     5.922]],
#   ['text/255',
#    [270, 3.881, 282, 2.976, 283, 5.513, 284, 5.798, 285, 4.908, 286, 3.032]],
#   ['text/256', [57, 4.431, 192, 5.539, 264, 4.815]],
#   ['text/257', [121, 4.945, 270, 4.592, 273, 6.052, 282, 3.52, 287, 7.09]],
#   ['text/258', [19, 3.33, 270, 4.592, 288, 6.141, 289, 8.098, 290, 7.868]],
#   ['text/259', [106, 4.072, 114, 4.315, 264, 4.815]],
#   ['text/260',
#    [19, 2.815, 45, 1.892, 270, 3.881, 275, 5.368, 285, 4.908, 291, 9.103]],
#   ['text/261', [192, 6.237, 264, 5.422]],
#   ['text/262', [92, 3.948, 265, 4.258, 270, 4.592, 292, 5.452, 293, 6.111]],
#   ['text/263', [19, 4.076, 264, 4.815, 294, 6.638]],
#   ['text/264', [57, 4.431, 264, 4.815, 295, 10.29]],
#   ['text/265', [264, 5.422, 265, 5.868]],
#   ['text/266', [101, 5.206, 264, 4.815, 265, 5.211]],
#   ['text/267', [45, 2.739, 264, 4.815, 265, 5.211]],
#   ['text/268', [176, 5.863, 264, 4.815, 265, 5.211]],
#   ['text/269', [23, 2.961, 264, 4.815, 265, 5.211]],
#   ['text/270', [296, 5.755, 297, 3.504, 298, 5.117]],
#   ['text/271', [297, 3.504, 298, 5.117, 299, 7.637]],
#   ['text/272', [297, 3.504, 298, 5.117, 300, 10.864]],
#   ['text/273', [121, 5.444, 297, 3.151, 298, 4.602, 301, 7.178]],
#   ['text/274', [114, 4.315, 297, 3.504, 298, 5.117]],
#   ['text/275', [160, 6.631, 297, 3.151, 298, 4.602, 302, 8.914]],
#   ['text/276',
#    [41, 2.455, 297, 2.623, 298, 3.83, 303, 8.132, 304, 4.302, 305, 5.571]],
#   ['text/277',
#    [282,
#     2.976,
#     297,
#     2.42,
#     298,
#     3.534,
#     306,
#     6.651,
#     307,
#     6.365,
#     308,
#     6.846,
#     309,
#     4.822]],
#   ['text/278', [297, 3.151, 298, 4.602, 310, 6.197, 311, 7.347]],
#   ['text/279', [118, 3.983, 297, 2.863, 298, 4.181, 302, 8.098, 312, 5.666]],
#   ['text/280', [297, 3.151, 298, 4.602, 306, 8.66, 313, 7.178]],
#   ['text/281', [198, 5.437, 282, 3.52, 297, 2.863, 298, 4.181, 314, 6.111]],
#   ['text/282',
#    [114, 3.23, 118, 3.649, 297, 2.623, 298, 3.83, 314, 5.598, 315, 6.349]],
#   ['text/283', [297, 3.151, 298, 4.602, 316, 9.77, 317, 9.254]],
#   ['text/284',
#    [118, 3.649, 297, 2.623, 298, 3.83, 308, 7.419, 312, 5.191, 318, 5.818]],
#   ['text/285', [118, 3.983, 297, 2.863, 298, 4.181, 305, 6.081, 315, 6.93]],
#   ['text/286',
#    [122,
#     2.44,
#     198,
#     4.266,
#     282,
#     2.762,
#     297,
#     2.246,
#     298,
#     3.28,
#     313,
#     5.117,
#     319,
#     6.597,
#     320,
#     5.437]],
#   ['text/287', [149, 2.507, 297, 2.863, 298, 4.181, 299, 6.24, 321, 8.407]],
#   ['text/288',
#    [41,
#     2.265,
#     114,
#     2.98,
#     122,
#     2.628,
#     297,
#     2.42,
#     298,
#     3.534,
#     314,
#     5.165,
#     322,
#     3.291]],
#   ['text/289', [297, 2.863, 298, 4.181, 305, 6.081, 323, 8.407, 324, 7.53]],
#   ['text/290', [28, 4.396, 297, 2.863, 298, 4.181, 305, 6.081, 325, 4.872]],
#   ['text/291', [297, 3.504, 298, 5.117, 305, 7.443]],
#   ['text/292', [297, 3.504, 298, 5.117, 305, 7.443]],
#   ['text/293', [297, 3.504, 298, 5.117, 305, 7.443]],
#   ['text/294',
#    [11,
#     3.017,
#     221,
#     4.819,
#     297,
#     3.384,
#     298,
#     3.28,
#     326,
#     4.522,
#     327,
#     1.904,
#     328,
#     3.758]],
#   ['text/295',
#    [298,
#     3.534,
#     327,
#     2.052,
#     329,
#     7.503,
#     330,
#     5.093,
#     331,
#     5.553,
#     332,
#     6.846,
#     333,
#     7.107]],
#   ['text/296',
#    [296,
#     3.974,
#     298,
#     3.534,
#     332,
#     6.846,
#     334,
#     5.642,
#     335,
#     6.254,
#     336,
#     5.642,
#     337,
#     6.846]],
#   ['text/297',
#    [36, 2.902, 297, 2.623, 298, 3.83, 338, 7.039, 339, 4.894, 340, 4.847]],
#   ['text/298',
#    [297,
#     3.054,
#     327,
#     1.665,
#     341,
#     4.508,
#     342,
#     2.751,
#     343,
#     3.955,
#     344,
#     5.768,
#     345,
#     5.398,
#     346,
#     2.288,
#     347,
#     4.864]],
#   ['text/299',
#    [60,
#     2.692,
#     193,
#     4.233,
#     297,
#     2.246,
#     328,
#     3.758,
#     348,
#     5.382,
#     349,
#     4.706,
#     350,
#     4.475,
#     351,
#     4.313]],
#   ['text/300', [35, 3.915, 352, 9.77, 353, 5.372, 354, 9.77]],
#   ['text/301',
#    [45, 2.051, 190, 4.08, 355, 7.208, 356, 5.3, 357, 8.132, 358, 8.132]],
#   ['text/302', [149, 2.759, 353, 5.372, 359, 5.511, 360, 3.403]],
#   ['text/303', [118, 4.384, 353, 5.372, 359, 5.511, 361, 9.77]],
#   ['text/304', [118, 4.384, 353, 5.372, 359, 5.511, 362, 9.254]],
#   ['text/305', [118, 4.384, 353, 5.372, 359, 5.511, 363, 9.254]],
#   ['text/306', [356, 7.973, 364, 12.234]],
#   ['text/307', [43, 4.622, 149, 2.759, 353, 5.372, 359, 5.511]],
#   ['text/308', [118, 4.384, 190, 4.902, 365, 5.462, 366, 7.347]],
#   ['text/309', [356, 7.08, 367, 7.03, 368, 8.915]],
#   ['text/310', [149, 3.068, 356, 7.08, 369, 10.864]],
#   ['text/311', [149, 3.068, 356, 7.08, 363, 10.29]],
#   ['text/312', [94, 6.991, 356, 7.973]],
#   ['text/313', [118, 3.983, 353, 4.88, 359, 5.007, 370, 8.876, 371, 8.876]],
#   ['text/314', [118, 4.384, 353, 5.372, 372, 8.288, 373, 9.254]],
#   ['text/315', [170, 6.237, 190, 4.902, 356, 6.367, 374, 8.457]],
#   ['text/316', [122, 3.423, 365, 5.462, 375, 7.033, 376, 6.257]],
#   ['text/317', [149, 2.759, 353, 5.372, 359, 5.511, 377, 6.322]],
#   ['text/318', [23, 2.419, 122, 3.109, 353, 4.88, 359, 5.007, 377, 5.743]],
#   ['text/319', [353, 5.973, 359, 6.128, 377, 7.03]],
#   ['text/320', [353, 5.973, 359, 6.128, 377, 7.03]],
#   ['text/321', [75, 6.907, 122, 3.423, 353, 5.372, 359, 5.511]],
#   ['text/322', [149, 2.759, 190, 4.902, 365, 5.462, 378, 8.288]],
#   ['text/323', [190, 4.902, 365, 5.462, 375, 7.033, 378, 8.288]],
#   ['text/324', [122, 3.109, 353, 4.88, 378, 7.53, 379, 4.827, 380, 6.621]],
#   ['text/325', [2, 3.398, 190, 4.902, 365, 5.462, 378, 8.288]],
#   ['text/326', [365, 4.963, 378, 7.53, 379, 4.827, 380, 6.621, 381, 5.053]],
#   ['text/327', [149, 2.507, 353, 4.88, 359, 5.007, 382, 7.683, 383, 7.284]],
#   ['text/328', [149, 2.759, 353, 5.372, 359, 5.511, 382, 8.457]],
#   ['text/329',
#    [41, 2.455, 122, 2.849, 353, 4.471, 359, 4.587, 362, 7.702, 384, 6.349]],
#   ['text/330', [23, 2.961, 385, 5.803, 386, 10.864]],
#   ['text/331', [13, 8.752, 385, 6.535]],
#   ['text/332', [385, 6.535, 387, 10.379]],
#   ['text/333', [18, 6.476, 23, 2.961, 385, 5.803]],
#   ['text/334', [3, 6.767, 23, 2.961, 385, 5.803]],
#   ['text/335', [207, 5.288, 388, 6.868, 389, 5.823, 390, 7.033]],
#   ['text/336',
#    [45, 2.051, 207, 4.402, 388, 5.717, 389, 4.847, 390, 5.854, 391, 4.772]],
#   ['text/337',
#    [45, 2.051, 207, 4.402, 304, 4.302, 388, 5.717, 389, 4.847, 390, 5.854]],
#   ['text/338', [207, 4.805, 304, 4.695, 388, 6.24, 389, 7.466]],
#   ['text/339', [45, 2.464, 207, 5.288, 389, 5.823, 390, 7.033]],
#   ['text/340', [101, 5.206, 385, 5.803, 392, 9.404]],
#   ['text/341', [13, 8.752, 385, 6.535]],
#   ['text/342', [3, 6.767, 19, 4.076, 122, 3.806]],
#   ['text/343', [3, 6.085, 23, 2.663, 385, 5.219, 393, 6.439]],
#   ['text/344', [23, 2.961, 385, 5.803, 387, 9.216]],
#   ['text/345', [60, 3.777, 331, 7.231, 389, 5.823, 394, 8.288]],
#   ['text/346', [121, 6.053, 395, 5.539, 396, 9.056]],
#   ['text/347', [385, 5.803, 388, 7.637, 397, 10.29]],
#   ['text/348', [3, 6.767, 101, 5.206, 389, 6.476]],
#   ['text/349', [19, 5.023, 26, 7.41, 101, 4.682]],
#   ['text/350', [3, 6.767, 385, 5.803, 398, 10.864]],
#   ['text/351', [116, 4.764, 122, 3.423, 394, 8.288, 395, 4.981]],
#   ['text/352', [26, 7.41, 106, 3.662, 186, 3.379, 389, 5.823]],
#   ['text/353', [23, 2.419, 60, 3.431, 106, 3.327, 389, 5.291, 399, 8.407]],
#   ['text/354', [36, 3.486, 37, 4.06, 49, 6.465, 385, 5.219]],
#   ['text/355', [49, 8.095, 385, 6.535]],
#   ['text/356', [49, 7.189, 122, 3.806, 395, 5.539]],
#   ['text/357', [49, 8.095, 385, 6.535]],
#   ['text/358', [385, 6.535, 387, 10.379]],
#   ['text/359', [13, 6.989, 122, 3.423, 385, 5.219, 400, 9.254]],
#   ['text/360', [114, 3.525, 401, 3.602, 402, 4.888, 403, 4.92, 404, 4.499]],
#   ['text/361', [65, 3.754, 149, 2.759, 223, 4.343, 405, 4.321]],
#   ['text/362', [36, 3.486, 223, 4.343, 405, 4.321, 406, 5.81]],
#   ['text/363', [2, 3.087, 223, 3.945, 405, 3.926, 407, 3.808, 408, 8.876]],
#   ['text/364', [403, 6.782, 409, 7.475]],
#   ['text/365', [286, 3.587, 346, 3.334, 403, 4.92, 410, 5.806, 411, 5.971]],
#   ['text/366', [223, 4.829, 412, 10.29, 413, 7.555]],
#   ['text/367', [286, 4.944, 406, 7.275]],
#   ['text/368', [403, 6.782, 414, 7.309]],
#   ['text/369', [415, 4.825, 416, 8.807]],
#   ['text/370', [41, 2.949, 65, 3.754, 286, 3.948, 417, 5.552]],
#   ['text/371', [286, 4.944, 403, 6.782]],
#   ['text/372', [407, 4.661, 415, 4.285, 418, 7.277]],
#   ['text/373', [41, 2.949, 45, 2.464, 286, 3.948, 406, 5.81]],
#   ['text/374', [286, 3.948, 407, 4.192, 415, 3.853, 418, 6.544]],
#   ['text/375', [286, 3.948, 407, 4.192, 417, 5.552, 419, 9.254]],
#   ['text/376', [406, 7.275, 420, 5.978]],
#   ['text/377', [114, 3.88, 228, 4.555, 416, 7.033, 421, 6.947]],
#   ['text/378', [406, 7.275, 409, 7.475]],
#   ['text/379', [114, 3.525, 228, 4.138, 286, 3.587, 405, 3.926, 416, 6.39]],
#   ['text/380', [328, 5.273, 415, 3.853, 420, 4.774, 422, 5.969]],
#   ['text/381', [195, 3.423, 286, 3.587, 416, 6.39, 423, 3.61, 424, 7.399]],
#   ['text/382', [228, 4.555, 286, 3.948, 416, 7.033, 425, 7.712]],
#   ['text/383', [328, 5.273, 409, 5.969, 411, 6.573, 415, 3.853]],
#   ['text/384', [286, 4.39, 403, 6.022, 417, 6.173]],
#   ['text/385', [328, 6.602, 426, 6.321]],
#   ['text/386', [65, 4.174, 286, 4.39, 407, 4.661]],
#   ['text/387', [416, 10.078]],
#   ['text/388', [41, 2.679, 286, 3.587, 403, 4.92, 410, 5.806, 411, 5.971]],
#   ['text/389', [405, 5.411, 406, 7.275]],
#   ['text/390',
#    [282, 3.225, 297, 2.623, 327, 2.224, 401, 3.3, 427, 7.702, 428, 4.87]],
#   ['text/391',
#    [297, 3.384, 327, 2.869, 427, 6.597, 429, 4.244, 430, 6.965, 431, 5.382]],
#   ['text/392',
#    [57,
#     3.06,
#     297,
#     2.42,
#     327,
#     2.052,
#     429,
#     4.572,
#     432,
#     3.065,
#     433,
#     6.846,
#     434,
#     5.858]],
#   ['text/393', [191, 3.716, 265, 4.686, 297, 3.151, 327, 2.671]],
#   ['text/394',
#    [2, 2.828, 115, 3.604, 208, 3.509, 297, 2.623, 327, 2.224, 429, 4.955]],
#   ['text/395',
#    [11,
#     2.483,
#     41,
#     1.73,
#     45,
#     1.445,
#     47,
#     2.806,
#     191,
#     2.18,
#     282,
#     2.273,
#     297,
#     1.848,
#     327,
#     1.567,
#     401,
#     2.326,
#     428,
#     3.432,
#     435,
#     3.171]],
#   ['text/396',
#    [41,
#     1.73,
#     45,
#     1.445,
#     47,
#     2.806,
#     191,
#     2.18,
#     282,
#     2.273,
#     297,
#     1.848,
#     327,
#     1.567,
#     346,
#     2.153,
#     436,
#     4.274,
#     437,
#     3.281,
#     438,
#     5.428]],
#   ['text/397',
#    [11,
#     2.815,
#     47,
#     3.181,
#     191,
#     2.472,
#     282,
#     2.577,
#     297,
#     2.096,
#     327,
#     1.777,
#     401,
#     2.637,
#     428,
#     3.891,
#     435,
#     3.596]],
#   ['text/398',
#    [47,
#     3.181,
#     191,
#     2.472,
#     282,
#     2.577,
#     297,
#     2.096,
#     327,
#     1.777,
#     346,
#     2.441,
#     435,
#     3.596,
#     439,
#     3.293,
#     440,
#     4.973]],
#   ['text/399',
#    [11,
#     2.815,
#     47,
#     3.181,
#     71,
#     3.496,
#     191,
#     2.472,
#     297,
#     2.096,
#     327,
#     1.777,
#     346,
#     2.441,
#     347,
#     5.19,
#     441,
#     5.512]],
#   ['text/400', [191, 3.376, 201, 5.316, 327, 2.427, 442, 8.876, 443, 5.133]],
#   ['text/401', [327, 2.671, 444, 7.41, 445, 4.885, 446, 5.288]],
#   ['text/402', [327, 2.671, 401, 3.965, 402, 5.38, 446, 5.288]],
#   ['text/403', [191, 3.716, 327, 2.671, 409, 5.969, 414, 5.837]],
#   ['text/404',
#    [43, 3.847, 327, 2.224, 414, 4.859, 428, 4.87, 446, 4.402, 447, 4.239]],
#   ['text/405', [191, 3.376, 327, 2.427, 401, 3.602, 428, 5.316, 448, 4.483]],
#   ['text/406', [327, 2.971, 346, 4.081, 444, 8.24]],
#   ['text/407',
#    [87, 3.104, 191, 3.093, 327, 2.224, 346, 3.055, 428, 4.87, 448, 4.107]],
#   ['text/408', [191, 3.376, 282, 3.52, 297, 2.863, 327, 2.427, 401, 3.602]],
#   ['text/409',
#    [191, 3.093, 297, 2.623, 327, 2.224, 346, 3.055, 411, 5.471, 449, 3.636]],
#   ['text/410', [327, 2.971, 411, 7.309, 446, 5.881]],
#   ['text/411', [297, 3.151, 327, 2.671, 346, 3.67, 446, 5.288]],
#   ['text/412', [327, 2.427, 401, 3.602, 428, 5.316, 446, 4.805, 448, 4.483]],
#   ['text/413', [87, 3.388, 327, 2.427, 428, 5.316, 448, 4.483, 450, 6.111]],
#   ['text/414', [191, 3.376, 282, 3.52, 297, 2.863, 327, 2.427, 401, 3.602]],
#   ['text/415', [327, 2.971, 444, 8.24, 451, 6.308]],
#   ['text/416', [327, 2.971, 414, 6.491, 452, 10.864]],
#   ['text/417', [41, 2.679, 297, 2.863, 327, 2.427, 446, 4.805, 451, 5.154]],
#   ['text/418', [41, 2.949, 327, 2.671, 414, 5.837, 446, 5.288]],
#   ['text/419',
#    [47, 3.674, 327, 3.033, 409, 4.584, 414, 4.483, 443, 4.339, 446, 4.061]],
#   ['text/420',
#    [37, 3.379, 45, 2.051, 149, 2.296, 191, 3.093, 346, 3.055, 453, 4.814]],
#   ['text/421', [27, 4.299, 37, 3.689, 346, 3.334, 454, 8.407, 455, 6.521]],
#   ['text/422', [456, 9.418]],
#   ['text/423', [457, 7.982, 458, 9.912, 459, 9.404]],
#   ['text/424', [23, 2.419, 118, 3.983, 346, 3.334, 460, 8.876, 461, 6.859]],
#   ['text/425', [149, 2.759, 346, 3.67, 462, 4.297, 463, 7.905]],
#   ['text/426', [23, 2.419, 149, 2.507, 346, 3.334, 464, 6.024, 465, 6.675]],
#   ['text/427', [27, 4.299, 37, 3.689, 346, 3.334, 454, 8.407, 455, 6.521]],
#   ['text/428', [346, 4.081, 466, 8.915, 467, 5.693]],
#   ['text/429', [346, 4.081, 467, 5.693, 468, 8.79]],
#   ['text/430', [346, 4.081, 467, 5.693, 469, 10.864]],
#   ['text/431', [346, 4.081, 467, 5.693, 470, 8.24]],
#   ['text/432', [149, 3.068, 346, 4.081, 471, 6.71]],
#   ['text/433', [346, 4.081, 462, 4.778, 471, 6.71]],
#   ['text/434', [149, 3.068, 346, 4.081, 471, 6.71]],
#   ['text/435', [346, 4.596, 471, 7.556]],
#   ['text/436', [56, 5.467, 149, 2.507, 346, 3.334, 471, 5.482, 472, 5.082]],
#   ['text/437', [27, 4.731, 37, 4.06, 346, 3.67, 473, 5.797]],
#   ['text/438', [191, 3.716, 346, 3.67, 453, 5.784, 474, 8.457]],
#   ['text/439', [149, 3.068, 346, 4.081, 475, 8.915]],
#   ['text/440', [149, 2.759, 346, 3.67, 476, 5.938, 477, 6.439]],
#   ['text/441', [346, 5.03, 470, 7.41, 478, 6.693]],
#   ['text/442', [346, 4.596, 479, 10.844]],
#   ['text/443', [346, 4.596, 480, 11.162]],
#   ['text/444', [346, 4.081, 481, 6.295, 482, 7.926]],
#   ['text/445', [346, 4.596, 462, 5.38]],
#   ['text/446', [2, 3.778, 346, 4.081, 462, 4.778]],
#   ['text/447', [346, 4.596, 475, 10.039]],
#   ['text/448', [23, 2.961, 118, 4.875, 346, 4.081]],
#   ['text/449', [346, 5.259]],
#   ['text/450',
#    [297, 2.623, 327, 2.224, 417, 4.621, 445, 4.066, 483, 4.278, 484, 7.419]],
#   ['text/451', [297, 2.863, 327, 2.427, 445, 4.438, 483, 4.67, 485, 6.081]],
#   ['text/452',
#    [41, 2.455, 45, 2.051, 297, 2.623, 327, 2.224, 445, 4.066, 483, 4.278]],
#   ['text/453', [41, 2.679, 297, 2.863, 327, 2.427, 445, 4.438, 483, 4.67]],
#   ['text/454', [41, 2.679, 66, 4.488, 74, 3.409, 483, 4.67, 486, 4.872]],
#   ['text/455', [65, 3.41, 297, 2.863, 327, 2.427, 445, 4.438, 483, 4.67]],
#   ['text/456',
#    [41, 2.455, 122, 2.849, 202, 4.731, 297, 2.623, 327, 2.224, 483, 4.278]],
#   ['text/457',
#    [41, 2.455, 122, 2.849, 297, 2.623, 327, 2.224, 445, 4.066, 483, 4.278]],
#   ['text/458', [65, 3.41, 202, 5.164, 297, 2.863, 327, 2.427, 483, 4.67]],
#   ['text/459',
#    [36, 2.902, 41, 2.455, 122, 2.849, 297, 2.623, 327, 2.224, 483, 4.278]],
#   ['text/460',
#    [41, 2.265, 297, 2.42, 327, 2.052, 445, 5.547, 483, 3.947, 487, 4.271]],
#   ['text/461', [149, 2.507, 297, 2.863, 327, 2.427, 445, 4.438, 483, 4.67]],
#   ['text/462', [267, 4.954, 483, 4.67, 486, 4.872, 488, 5.63, 489, 6.111]],
#   ['text/463', [41, 2.679, 297, 2.863, 327, 2.427, 445, 4.438, 483, 4.67]],
#   ['text/464',
#    [23, 2.217, 149, 2.296, 297, 2.623, 327, 2.224, 445, 4.066, 483, 4.278]],
#   ['text/465',
#    [11, 3.523, 23, 2.217, 41, 2.455, 445, 4.066, 483, 4.278, 490, 5.051]],
#   ['text/466', [41, 2.679, 297, 2.863, 327, 2.427, 445, 4.438, 483, 4.67]],
#   ['text/467', [267, 4.954, 327, 2.427, 483, 4.67, 487, 5.053, 489, 6.111]],
#   ['text/468', [149, 2.507, 297, 2.863, 327, 2.427, 445, 4.438, 483, 4.67]],
#   ['text/469', [327, 2.671, 483, 5.14, 491, 8.288, 492, 5.784]],
#   ['text/470',
#    [23,
#     2.045,
#     149,
#     2.119,
#     267,
#     4.188,
#     327,
#     2.052,
#     483,
#     3.947,
#     489,
#     5.165,
#     491,
#     6.365]],
#   ['text/471',
#    [37,
#     3.118,
#     327,
#     2.052,
#     483,
#     3.947,
#     489,
#     5.165,
#     491,
#     6.365,
#     493,
#     4.66,
#     494,
#     5.993]],
#   ['text/472',
#    [2, 2.828, 297, 2.623, 327, 2.224, 445, 4.066, 483, 4.278, 491, 6.899]],
#   ['text/473',
#    [37,
#     3.118,
#     327,
#     2.052,
#     483,
#     3.947,
#     491,
#     6.365,
#     493,
#     4.66,
#     494,
#     5.993,
#     495,
#     7.503]],
#   ['text/474', [327, 2.671, 483, 5.14, 496, 4.114, 497, 7.55]],
#   ['text/475', [202, 5.164, 267, 4.954, 483, 4.67, 489, 6.111, 498, 5.266]],
#   ['text/476', [267, 5.453, 483, 5.14, 489, 6.726, 498, 5.797]],
#   ['text/477', [267, 4.954, 327, 2.427, 483, 4.67, 489, 6.111, 496, 3.737]],
#   ['text/478', [202, 6.321, 483, 5.716, 498, 6.446]],
#   ['text/479', [41, 2.679, 327, 2.427, 483, 4.67, 492, 5.254, 496, 3.737]],
#   ['text/480', [2, 3.398, 445, 4.885, 499, 5.758, 500, 4.224]],
#   ['text/481', [2, 3.087, 445, 4.438, 500, 3.838, 501, 7.399, 502, 5.154]],
#   ['text/482', [2, 3.398, 445, 4.885, 500, 4.224, 503, 8.144]],
#   ['text/483', [2, 3.398, 445, 4.885, 500, 4.224, 504, 6.795]],
#   ['text/484', [2, 3.087, 445, 4.438, 486, 4.872, 500, 3.838, 502, 5.154]],
#   ['text/485', [2, 3.398, 191, 3.716, 499, 5.758, 500, 4.224]],
#   ['text/486', [499, 7.21, 500, 5.29]],
#   ['text/487', [149, 3.068, 500, 4.698, 505, 7.374]],
#   ['text/488', [500, 5.29, 505, 8.304]],
#   ['text/489', [226, 6.106, 500, 4.698, 505, 7.374]],
#   ['text/490', [36, 3.167, 346, 3.334, 414, 5.303, 500, 3.838, 505, 6.024]],
#   ['text/491', [346, 3.67, 500, 4.224, 506, 7.477, 507, 6.544]],
#   ['text/492', [2, 3.087, 445, 4.438, 499, 5.231, 500, 3.838, 508, 7.006]],
#   ['text/493', [118, 3.983, 445, 4.438, 500, 3.838, 502, 5.154, 509, 5.921]],
#   ['text/494',
#    [2, 2.828, 114, 3.23, 346, 3.055, 486, 4.464, 500, 3.516, 502, 4.722]],
#   ['text/495', [149, 2.759, 445, 4.885, 500, 4.224, 510, 8.66]],
#   ['text/496', [45, 2.238, 445, 4.438, 486, 4.872, 500, 3.838, 502, 5.154]],
#   ['text/497', [149, 2.507, 445, 4.438, 486, 4.872, 500, 3.838, 502, 5.154]],
#   ['text/498',
#    [41, 2.455, 45, 2.051, 445, 4.066, 486, 4.464, 500, 3.516, 502, 4.722]],
#   ['text/499', [41, 2.679, 445, 4.438, 486, 4.872, 500, 3.838, 502, 5.154]],
#   ['text/500', [41, 2.679, 445, 4.438, 486, 4.872, 500, 3.838, 502, 5.154]],
#   ['text/501', [500, 4.698, 505, 7.374, 511, 7.189]],
#   ['text/502', [346, 4.081, 500, 4.698, 505, 7.374]],
#   ['text/503', [423, 3.974, 493, 6.068, 500, 4.224, 505, 6.631]],
#   ['text/504', [500, 4.698, 505, 7.374, 512, 9.912]],
#   ['text/505', [346, 4.081, 513, 7.374, 514, 5.078]],
#   ['text/506', [513, 8.304, 514, 5.718]],
#   ['text/507', [346, 4.081, 500, 4.698, 513, 7.374]],
#   ['text/508', [500, 4.698, 513, 7.374, 514, 5.078]],
#   ['text/509', [500, 4.698, 513, 7.374, 514, 5.078]],
#   ['text/510', [432, 3.991, 515, 5.265, 516, 5.204, 517, 6.051]],
#   ['text/511', [515, 6.593, 516, 6.517]],
#   ['text/512', [118, 4.384, 515, 5.265, 516, 5.204, 518, 7.41]],
#   ['text/513', [23, 2.961, 515, 5.854, 516, 5.787]],
#   ['text/514', [23, 2.663, 515, 5.265, 516, 5.204, 519, 4.864]],
#   ['text/515', [127, 5.648, 149, 2.507, 515, 4.783, 516, 4.728, 517, 5.497]],
#   ['text/516', [515, 5.854, 516, 5.787, 519, 5.409]],
#   ['text/517', [23, 2.419, 515, 4.783, 516, 4.728, 519, 4.419, 520, 7.868]],
#   ['text/518', [393, 5.85, 515, 4.783, 516, 4.728, 517, 5.497, 521, 6.475]],
#   ['text/519', [23, 2.419, 515, 4.783, 516, 4.728, 519, 4.419, 520, 7.868]],
#   ['text/520', [515, 5.265, 516, 5.204, 517, 6.051, 521, 7.127]],
#   ['text/521', [30, 3.879, 432, 3.626, 515, 4.783, 516, 4.728, 517, 5.497]],
#   ['text/522', [515, 5.854, 516, 5.787, 519, 5.409]],
#   ['text/523', [122, 3.109, 515, 4.783, 516, 4.728, 517, 5.497, 521, 6.475]],
#   ['text/524', [516, 6.517, 522, 9.772]],
#   ['text/525', [515, 6.593, 516, 6.517]],
#   ['text/526', [516, 5.787, 523, 8.17, 524, 6.446]],
#   ['text/527', [515, 5.854, 516, 5.787, 524, 6.446]],
#   ['text/528', [515, 5.854, 516, 5.787, 517, 6.728]],
#   ['text/529', [515, 5.854, 516, 5.787, 517, 6.728]],
#   ['text/530', [432, 3.991, 515, 5.265, 516, 5.204, 517, 6.051]],
#   ['text/531', [515, 5.265, 516, 5.204, 517, 6.051, 521, 7.127]],
#   ['text/532', [23, 2.419, 515, 4.783, 516, 4.728, 517, 5.497, 521, 6.475]],
#   ['text/533', [432, 3.991, 515, 5.265, 516, 5.204, 517, 6.051]],
#   ['text/534', [30, 4.27, 515, 5.265, 516, 5.204, 517, 6.051]],
#   ['text/535', [515, 5.854, 516, 5.787, 517, 6.728]],
#   ['text/536', [432, 3.991, 515, 5.265, 516, 5.204, 517, 6.051]],
#   ['text/537',
#    [30, 3.554, 515, 4.382, 516, 4.332, 517, 5.036, 525, 5.339, 526, 5.381]],
#   ['text/538', [118, 4.384, 516, 5.204, 518, 7.41, 522, 7.804]],
#   ['text/539', [515, 5.265, 516, 5.204, 517, 6.051, 521, 7.127]],
#   ['text/540', [35, 4.353, 37, 4.515, 527, 7.596]],
#   ['text/541', [23, 2.663, 116, 4.764, 432, 3.991, 527, 6.831]],
#   ['text/542', [35, 4.353, 186, 3.758, 527, 7.596]],
#   ['text/543', [37, 4.515, 432, 4.438, 527, 7.596]],
#   ['text/544', [304, 4.302, 432, 4.807, 527, 5.685, 528, 3.228, 529, 5.598]],
#   ['text/545', [122, 3.806, 432, 4.438, 530, 9.404]],
#   ['text/546', [251, 5.595, 304, 4.695, 432, 3.626, 530, 7.683, 531, 8.098]],
#   ['text/547', [530, 10.59, 532, 7.916]],
#   ['text/548', [530, 10.59, 533, 8.382]],
#   ['text/549', [23, 2.961, 432, 4.438, 530, 9.404]],
#   ['text/550', [35, 4.353, 432, 4.438, 534, 6.827]],
#   ['text/551', [35, 4.353, 432, 4.438, 534, 6.827]],
#   ['text/552', [23, 2.663, 35, 3.915, 432, 3.991, 534, 6.139]],
#   ['text/553', [23, 2.663, 35, 3.915, 432, 3.991, 534, 6.139]],
#   ['text/554', [23, 2.663, 35, 3.915, 432, 3.991, 534, 6.139]],
#   ['text/555',
#    [19, 2.815, 23, 2.045, 35, 4.445, 395, 3.825, 519, 3.736, 535, 6.365]],
#   ['text/556',
#    [35, 3.258, 185, 4.665, 367, 5.262, 519, 4.049, 535, 6.899, 536, 5.08]],
#   ['text/557', [185, 5.605, 519, 4.864, 532, 6.322, 535, 8.288]],
#   ['text/558', [385, 5.219, 519, 4.864, 533, 6.693, 535, 8.288]],
#   ['text/559', [432, 4.438, 519, 5.409, 535, 9.216]],
#   ['text/560', [23, 2.961, 35, 4.353, 186, 3.758]],
#   ['text/561', [23, 2.419, 35, 3.557, 36, 3.167, 186, 3.07, 537, 5.545]],
#   ['text/562', [23, 2.961, 35, 4.353, 207, 5.881]],
#   ['text/563', [35, 4.902, 186, 4.232]],
#   ['text/564', [35, 4.353, 36, 3.877, 538, 10.864]],
#   ['text/565', [37, 4.06, 116, 4.764, 432, 3.991, 539, 8.288]],
#   ['text/566', [432, 4.998, 540, 12.234]],
#   ['text/567', [122, 3.806, 432, 4.438, 541, 10.864]],
#   ['text/568', [122, 3.806, 432, 4.438, 542, 10.864]],
#   ['text/569', [37, 4.515, 432, 4.438, 543, 8.678]],
#   ['text/570', [417, 7.955]],
#   ['text/571', [417, 7.955]],
#   ['text/572', [224, 6.933]],
#   ['text/573', [544, 8.487]],
#   ['text/574', [417, 7.955]],
#   ['text/575', [417, 6.952, 544, 7.417]],
#   ['text/576', [432, 4.998, 473, 7.259]],
#   ['text/577', [2, 3.778, 244, 6.603, 473, 6.446]],
#   ['text/578', [53, 6.278, 174, 6.573, 214, 5.501, 448, 4.935]],
#   ['text/579', [213, 8.041, 214, 6.117, 544, 6.586]],
#   ['text/580', [149, 3.455, 525, 8.033]],
#   ['text/581', [417, 6.952, 545, 8.304]],
#   ['text/582', [544, 8.487]],
#   ['text/583', [546, 8.908]],
#   ['text/584', [224, 6.058, 546, 7.784]],
#   ['text/585', [211, 5.47, 546, 7.784]],
#   ['text/586', [92, 5.442, 547, 10.379]],
#   ['text/587', [473, 7.259, 548, 11.588]],
#   ['text/588', [473, 7.259, 549, 9.772]],
#   ['text/589', [550, 12.409]],
#   ['text/590', [544, 8.487]],
#   ['text/591', [417, 7.955]],
#   ['text/592', [448, 7.071]],
#   ['text/593', [202, 8.145]],
#   ['text/594', [551, 10.29, 552, 8.915, 553, 10.864]],
#   ['text/595', [546, 7.784, 554, 10.59]],
#   ['text/596', [544, 8.487]],
#   ['text/597', [59, 7.556, 214, 6.888]],
#   ['text/598', [224, 6.058, 544, 7.417]],
#   ['text/599', [114, 4.859, 555, 10.59]],
#   ['text/600', [556, 8.407, 557, 5.921, 558, 5.034, 559, 5.545, 560, 3.101]],
#   ['text/601', [88, 4.495, 560, 3.414, 561, 6.465, 562, 8.457]],
#   ['text/602',
#    [60, 3.144, 92, 3.617, 559, 5.08, 560, 2.842, 563, 4.741, 564, 5.174]],
#   ['text/603', [110, 4.859, 560, 3.414, 565, 9.77, 566, 6.631]],
#   ['text/604', [560, 3.796, 567, 7.555, 568, 10.29]],
#   ['text/605',
#    [88, 3.741, 558, 4.612, 560, 2.842, 564, 5.174, 569, 4.859, 570, 3.496]],
#   ['text/606', [92, 4.346, 558, 5.541, 560, 3.414, 570, 4.2]],
#   ['text/607',
#    [88,
#     3.204,
#     101,
#     3.338,
#     127,
#     4.431,
#     560,
#     2.434,
#     570,
#     2.994,
#     571,
#     5.715,
#     572,
#     5.715,
#     573,
#     4.795]],
#   ['text/608',
#    [36,
#     2.677,
#     88,
#     3.452,
#     225,
#     5.642,
#     537,
#     4.687,
#     560,
#     2.622,
#     570,
#     3.225,
#     574,
#     5.437]],
#   ['text/609', [88, 4.495, 558, 5.541, 560, 3.414, 570, 4.2]],
#   ['text/610', [282, 3.52, 560, 3.101, 570, 3.815, 575, 7.006, 576, 6.475]],
#   ['text/611',
#    [45,
#     1.892,
#     88,
#     3.452,
#     560,
#     2.622,
#     570,
#     3.225,
#     573,
#     5.165,
#     577,
#     5.922,
#     578,
#     6.157]],
#   ['text/612',
#    [88,
#     3.204,
#     282,
#     2.762,
#     560,
#     2.434,
#     570,
#     2.994,
#     575,
#     5.497,
#     576,
#     7.655,
#     579,
#     5.805]],
#   ['text/613',
#    [23,
#     2.045,
#     45,
#     1.892,
#     50,
#     4.384,
#     560,
#     2.622,
#     570,
#     3.225,
#     580,
#     5.993,
#     581,
#     5.165]],
#   ['text/614', [23, 2.419, 92, 3.948, 560, 3.101, 570, 3.815, 582, 6.475]],
#   ['text/615', [88, 4.495, 558, 5.541, 560, 3.414, 570, 4.2]],
#   ['text/616', [88, 4.495, 560, 3.414, 564, 6.216, 570, 4.2]],
#   ['text/617',
#    [88, 3.741, 127, 5.174, 560, 2.842, 564, 5.174, 570, 3.496, 573, 5.598]],
#   ['text/618',
#    [30,
#     3.279,
#     88,
#     3.452,
#     101,
#     3.596,
#     423,
#     3.052,
#     560,
#     2.622,
#     570,
#     3.225,
#     574,
#     5.437]],
#   ['text/619', [560, 3.414, 564, 6.216, 569, 5.837, 570, 4.2]],
#   ['text/620', [45, 2.238, 88, 4.083, 560, 3.101, 564, 5.648, 570, 3.815]],
#   ['text/621',
#    [88,
#     3.452,
#     282,
#     2.976,
#     525,
#     4.926,
#     560,
#     2.622,
#     570,
#     3.225,
#     574,
#     5.437,
#     583,
#     7.503]],
#   ['text/622', [558, 5.541, 560, 3.414, 570, 4.2, 581, 6.726]],
#   ['text/623', [45, 2.967, 304, 4.302, 529, 5.598, 558, 4.612, 564, 5.174]],
#   ['text/624', [282, 3.52, 560, 3.101, 570, 3.815, 576, 6.475, 579, 7.399]],
#   ['text/625', [45, 2.464, 558, 5.541, 560, 3.414, 570, 4.2]],
#   ['text/626',
#    [45,
#     1.756,
#     282,
#     2.762,
#     304,
#     3.684,
#     529,
#     4.795,
#     560,
#     2.434,
#     570,
#     2.994,
#     575,
#     5.497,
#     576,
#     5.081]],
#   ['text/627', [23, 2.419, 523, 6.675, 560, 3.101, 564, 5.648, 570, 3.815]],
#   ['text/628', [45, 2.238, 560, 3.101, 570, 3.815, 584, 5.072, 585, 7.399]],
#   ['text/629', [45, 2.739, 560, 3.796, 586, 7.872]],
#   ['text/630', [57, 4.99, 149, 3.455]],
#   ['text/631', [57, 4.99, 587, 6.021]],
#   ['text/632', [41, 3.693, 57, 4.99]],
#   ['text/633', [57, 4.431, 587, 5.346, 588, 5.272]],
#   ['text/634', [41, 2.679, 57, 3.62, 122, 3.109, 587, 4.368, 589, 4.597]],
#   ['text/635', [23, 2.217, 41, 2.455, 57, 4.799, 587, 4.002, 589, 4.212]],
#   ['text/636', [41, 2.949, 57, 3.985, 587, 4.808, 589, 5.061]],
#   ['text/637', [41, 2.949, 57, 3.985, 587, 4.808, 589, 5.061]],
#   ['text/638', [41, 2.679, 57, 3.62, 587, 4.368, 589, 4.597, 590, 7.53]],
#   ['text/639', [591, 9.418]],
#   ['text/640', [149, 3.455, 591, 8.23]],
#   ['text/641', [23, 2.961, 149, 3.068, 591, 7.309]],
#   ['text/642', [591, 9.418]],
#   ['text/643', [367, 7.03, 589, 5.627, 592, 6.269]],
#   ['text/644', [587, 5.346, 588, 5.272, 593, 8.482]],
#   ['text/645', [591, 8.23, 594, 11.162]],
#   ['text/646', [591, 7.309, 595, 9.216, 596, 8.24]],
#   ['text/647', [591, 7.309, 597, 8.24, 598, 9.912]],
#   ['text/648', [545, 7.374, 591, 7.309, 593, 8.482]],
#   ['text/649', [591, 8.23, 594, 11.162]],
#   ['text/650', [149, 3.954]],
#   ['text/651', [599, 8.033, 600, 8.23]],
#   ['text/652', []],
#   ['text/653', [19, 4.076, 60, 4.2, 601, 7.479]],
#   ['text/654', []],
#   ['text/655', [118, 4.875, 592, 6.269, 602, 9.216]],
#   ['text/656', [149, 2.759, 367, 6.322, 589, 5.061, 592, 5.638]],
#   ['text/657', [603, 9.591]],
#   ['text/658', [41, 3.693, 587, 6.021]],
#   ['text/659', [57, 5.71]],
#   ['text/660', [604, 14.0]],
#   ['text/661', [30, 3.879, 41, 2.679, 185, 5.092, 304, 4.695, 605, 7.53]],
#   ['text/662', []],
#   ['text/663', [28, 6.058, 36, 4.366]],
#   ['text/664', [606, 11.669]],
#   ['text/665', []],
#   ['text/666', [185, 7.018, 607, 8.988]],
#   ['text/667', [11, 6.065]],
#   ['text/668', [28, 5.38, 391, 6.375, 596, 8.24]],
#   ['text/669', [28, 6.058, 36, 4.366]],
#   ['text/670', [127, 6.913, 136, 6.891, 607, 7.982]],
#   ['text/671', [563, 8.162]],
#   ['text/672', [607, 10.286]],
#   ['text/673', [391, 8.215]],
#   ['text/674', []],
#   ['text/675', [608, 12.118]],
#   ['text/676', []],
#   ['text/677', [193, 7.436, 563, 7.133]],
#   ['text/678', [41, 4.226]],
#   ['text/679', [563, 8.162]],
#   ['text/680', [563, 7.133, 609, 12.234]],
#   ['text/681', [173, 6.642, 607, 8.988]],
#   ['text/682', [30, 4.27, 563, 5.696, 610, 8.66, 611, 7.905]],
#   ['text/683', [30, 4.27, 563, 5.696, 610, 8.66, 612, 5.552]],
#   ['text/684', [30, 4.27, 165, 6.868, 563, 5.696, 610, 8.66]],
#   ['text/685', [30, 4.748, 165, 7.637, 563, 6.334]],
#   ['text/686', [30, 4.748, 563, 6.334, 610, 9.63]],
#   ['text/687', [613, 11.669]],
#   ['text/688', [30, 4.748, 596, 8.24, 614, 7.68]],
#   ['text/689', [615, 12.409]],
#   ['text/690', [57, 4.431, 186, 3.758, 616, 4.572]],
#   ['text/691', [19, 3.665, 186, 3.379, 616, 5.634]],
#   ['text/692', [186, 4.232, 616, 5.148]],
#   ['text/693', [186, 3.758, 616, 4.572, 617, 9.912]],
#   ['text/694', [186, 4.232, 616, 5.148]],
#   ['text/695', [118, 4.384, 186, 3.379, 616, 4.111, 618, 6.3]],
#   ['text/696', [186, 3.07, 589, 4.597, 616, 5.271, 617, 8.098]],
#   ['text/697',
#    [23, 2.045, 176, 4.049, 186, 2.595, 589, 3.886, 601, 5.165, 616, 4.668]],
#   ['text/698', [41, 2.949, 122, 3.423, 186, 3.379, 616, 4.111]],
#   ['text/699', [19, 3.33, 149, 2.507, 186, 3.07, 588, 4.307, 616, 3.735]],
#   ['text/700', [186, 3.379, 589, 5.061, 616, 5.634]],
#   ['text/701',
#    [23,
#     2.045,
#     28,
#     3.716,
#     186,
#     2.595,
#     360,
#     2.613,
#     616,
#     3.157,
#     618,
#     4.838,
#     619,
#     5.691]],
#   ['text/702', [45, 2.464, 186, 3.379, 616, 4.111, 620, 8.457]],
#   ['text/703',
#    [122, 2.628, 186, 2.595, 198, 6.795, 360, 2.613, 616, 3.157, 621, 7.107]],
#   ['text/704', [186, 3.758, 616, 4.572, 622, 8.482]],
#   ['text/705', [186, 3.379, 360, 3.403, 616, 4.111, 622, 7.627]],
#   ['text/706', [57, 3.62, 186, 3.07, 423, 3.61, 616, 3.735, 623, 5.704]],
#   ['text/707',
#    [186, 2.813, 198, 4.982, 266, 5.571, 267, 4.539, 616, 3.422, 624, 6.673]],
#   ['text/708', [118, 3.649, 186, 2.813, 198, 7.207, 616, 3.422, 618, 5.244]],
#   ['text/709',
#    [41, 2.455, 57, 3.317, 122, 2.849, 186, 2.813, 360, 2.832, 616, 3.422]],
#   ['text/710',
#    [92,
#     3.337,
#     186,
#     2.595,
#     360,
#     2.613,
#     547,
#     6.365,
#     560,
#     2.622,
#     616,
#     3.157,
#     618,
#     4.838]],
#   ['text/711', [19, 3.665, 121, 5.444, 186, 3.379, 616, 4.111]],
#   ['text/712', [19, 3.665, 186, 3.379, 616, 5.634]],
#   ['text/713', [19, 3.33, 446, 4.805, 599, 5.828, 616, 5.271]],
#   ['text/714', [186, 4.232, 616, 5.148]],
#   ['text/715',
#    [282, 2.976, 446, 4.061, 616, 4.668, 625, 4.374, 626, 6.071, 627, 6.846]],
#   ['text/716', [23, 2.663, 149, 2.759, 186, 3.379, 616, 4.111]],
#   ['text/717', [186, 4.232, 616, 5.148]],
#   ['text/718', [23, 2.663, 41, 2.949, 186, 3.379, 616, 4.111]],
#   ['text/719', [41, 2.679, 45, 2.238, 186, 3.07, 360, 3.091, 616, 3.735]],
#   ['text/720', [60, 3.431, 101, 4.254, 628, 3.407, 629, 8.876, 630, 6.521]],
#   ['text/721',
#    [23,
#     1.898,
#     60,
#     2.692,
#     111,
#     3.861,
#     458,
#     6.354,
#     459,
#     6.029,
#     628,
#     2.673,
#     631,
#     6.965,
#     632,
#     6.029]],
#   ['text/722',
#    [111, 4.508, 628, 3.122, 633, 4.539, 634, 5.008, 635, 5.051, 636, 5.036]],
#   ['text/723',
#    [111,
#     4.159,
#     261,
#     4.014,
#     628,
#     2.88,
#     633,
#     4.188,
#     634,
#     4.621,
#     635,
#     4.66,
#     636,
#     4.647]],
#   ['text/724',
#    [45, 2.051, 111, 4.508, 633, 4.539, 634, 5.008, 635, 5.051, 636, 5.036]],
#   ['text/725',
#    [45, 2.051, 111, 4.508, 633, 4.539, 634, 5.008, 635, 5.051, 636, 5.036]],
#   ['text/726',
#    [111, 4.508, 261, 4.35, 633, 4.539, 634, 5.008, 635, 5.051, 636, 5.036]],
#   ['text/727',
#    [35,
#     2.604,
#     111,
#     3.602,
#     112,
#     3.301,
#     628,
#     2.494,
#     633,
#     3.627,
#     637,
#     3.773,
#     638,
#     4.059,
#     639,
#     3.659,
#     640,
#     5.76]],
#   ['text/728',
#    [35,
#     2.604,
#     112,
#     3.301,
#     633,
#     3.627,
#     639,
#     3.659,
#     640,
# ...
#      '18609': defaultdict(list, {}),
#      '18612': defaultdict(list, {}),
#      '18617': defaultdict(list, {}),
#      '18619': defaultdict(list, {}),
#      '18649': defaultdict(list, {}),
#      '18652': defaultdict(list, {}),
#      '18655': defaultdict(list, {}),
#      '18656': defaultdict(list, {}),
#      '18657': defaultdict(list, {}),
#      '18667': defaultdict(list, {}),
#      '18669': defaultdict(list, {}),
#      '18670': defaultdict(list, {}),
#      '18671': defaultdict(list, {}),
#      '18672': defaultdict(list, {}),
#      '18692': defaultdict(list, {}),
#      '18696': defaultdict(list, {}),
#      '18697': defaultdict(list, {}),
#      '18698': defaultdict(list, {}),
#      '18699': defaultdict(list, {}),
#      '19987': defaultdict(list, {}),
#      '19988': defaultdict(list, {}),
#      '19989': defaultdict(list, {}),
#      '19991': defaultdict(list, {}),
#      '19997': defaultdict(list, {}),
#      '20035': defaultdict(list, {}),
#      '20654': defaultdict(list, {}),
#      '20741': defaultdict(list, {}),
#      '20743': defaultdict(list, {}),
#      '21621': defaultdict(list, {}),
#      '21622': defaultdict(list, {}),
#      '21623': defaultdict(list, {}),
#      '21626': defaultdict(list, {}),
#      '21634': defaultdict(list, {}),
#      '21635': defaultdict(list, {}),
#      '21637': defaultdict(list, {}),
#      '21639': defaultdict(list, {}),
#      '22012': defaultdict(list, {}),
#      '22324': defaultdict(list, {}),
#      '22326': defaultdict(list, {}),
#      '22327': defaultdict(list, {}),
#      '22328': defaultdict(list, {}),
#      '22329': defaultdict(list, {}),
#      '22642': defaultdict(list, {}),
#      '22684': defaultdict(list, {}),
#      '22687': defaultdict(list, {}),
#      '22688': defaultdict(list, {}),
#      '22708': defaultdict(list, {}),
#      '22709': defaultdict(list, {}),
#      '22746': defaultdict(list, {}),
#      '22804': defaultdict(list, {}),
#      '22821': defaultdict(list, {}),
#      '23044': defaultdict(list, {}),
#      '23045': defaultdict(list, {}),
#      '23046': defaultdict(list, {}),
#      '23128': defaultdict(list, {}),
#      '23148': defaultdict(list, {}),
#      '23157': defaultdict(list, {}),
#      '23279': defaultdict(list, {}),
#      '23308': defaultdict(list, {}),
#      '23335': defaultdict(list, {}),
#      '23385': defaultdict(list, {}),
#      '23386': defaultdict(list, {}),
#      '23402': defaultdict(list, {}),
#      '23426': defaultdict(list, {}),
#      '23441': defaultdict(list, {}),
#      '23442': defaultdict(list, {}),
#      '23443': defaultdict(list, {}),
#      '23444': defaultdict(list, {})},
#     '_index': 655}],
#   ['bookshelf', {'text': {'9430': defaultdict(list, {})}, '_index': 3205}],
#   ['boon', {'text': {'5995': defaultdict(list, {})}, '_index': 2617}],
#   ['boost',
#    {'text': {'275': defaultdict(list, {}),
#      '279': defaultdict(list, {}),
#      '13450': defaultdict(list, {})},
#     '_index': 302}],
#   ['boot', {'text': {'23391': defaultdict(list, {})}, '_index': 5851}],
#   ['bootup', {'text': {'21888': defaultdict(list, {})}, '_index': 5183}],
#   ['booz', {'text': {'1144': defaultdict(list, {})}, '_index': 937}],
#   ['border',
#    {'text': {'23185': defaultdict(list, {}), '23187': defaultdict(list, {})},
#     '_index': 5742}],
#   ['bore', {'text': {'22371': defaultdict(list, {})}, '_index': 5268}],
#   ['born',
#    {'text': {'583': defaultdict(list, {}),
#      '584': defaultdict(list, {}),
#      '585': defaultdict(list, {}),
#      '595': defaultdict(list, {}),
#      '6407': defaultdict(list, {}),
#      '6408': defaultdict(list, {}),
#      '6410': defaultdict(list, {}),
#      '6441': defaultdict(list, {}),
#      '6447': defaultdict(list, {}),
#      '6448': defaultdict(list, {}),
#      '6449': defaultdict(list, {}),
#      '6464': defaultdict(list, {}),
#      '6465': defaultdict(list, {}),
#      '6477': defaultdict(list, {}),
#      '6485': defaultdict(list, {}),
#      '6490': defaultdict(list, {}),
#      '6492': defaultdict(list, {}),
#      '6493': defaultdict(list, {}),
#      '6496': defaultdict(list, {}),
#      '6497': defaultdict(list, {}),
#      '18502': defaultdict(list, {}),
#      '18511': defaultdict(list, {}),
#      '18522': defaultdict(list, {}),
#      '18523': defaultdict(list, {}),
#      '18524': defaultdict(list, {}),
#      '18525': defaultdict(list, {}),
#      '18526': defaultdict(list, {}),
#      '18536': defaultdict(list, {}),
#      '18538': defaultdict(list, {}),
#      '18542': defaultdict(list, {}),
#      '18544': defaultdict(list, {}),
#      '18575': defaultdict(list, {}),
#      '18578': defaultdict(list, {}),
#      '18579': defaultdict(list, {}),
#      '18599': defaultdict(list, {}),
#      '19880': defaultdict(list, {}),
#      '19881': defaultdict(list, {}),
#      '19884': defaultdict(list, {}),
#      '19887': defaultdict(list, {}),
#      '22303': defaultdict(list, {}),
#      '22305': defaultdict(list, {}),
#      '22314': defaultdict(list, {}),
#      '22316': defaultdict(list, {}),
#      '22317': defaultdict(list, {}),
#      '22822': defaultdict(list, {}),
#      '22931': defaultdict(list, {}),
#      '23010': defaultdict(list, {}),
#      '23531': defaultdict(list, {}),
#      '23533': defaultdict(list, {}),
#      '23584': defaultdict(list, {})},
#     '_index': 546}],
#   ['borrow', {'text': {'4561': defaultdict(list, {})}, '_index': 2315}],
#   ['boss',
#    {'text': {'2164': defaultdict(list, {}),
#      '2703': defaultdict(list, {}),
#      '2704': defaultdict(list, {}),
#      '2705': defaultdict(list, {}),
#      '2706': defaultdict(list, {}),
#      '2716': defaultdict(list, {}),
#      '2719': defaultdict(list, {}),
#      '13501': defaultdict(list, {}),
#      '13502': defaultdict(list, {}),
#      '13503': defaultdict(list, {}),
#      '13504': defaultdict(list, {}),
#      '13505': defaultdict(list, {}),
#      '13506': defaultdict(list, {}),
#      '13507': defaultdict(list, {}),
#      '13508': defaultdict(list, {}),
#      '13509': defaultdict(list, {}),
#      '13510': defaultdict(list, {}),
#      '13511': defaultdict(list, {}),
#      '13518': defaultdict(list, {}),
#      '13521': defaultdict(list, {}),
#      '13525': defaultdict(list, {}),
#      '13526': defaultdict(list, {}),
#      '13528': defaultdict(list, {}),
#      '13533': defaultdict(list, {}),
#      '13561': defaultdict(list, {}),
#      '13569': defaultdict(list, {}),
#      '13593': defaultdict(list, {}),
#      '17289': defaultdict(list, {}),
#      '17423': defaultdict(list, {}),
#      '17449': defaultdict(list, {}),
#      '20950': defaultdict(list, {}),
#      '21314': defaultdict(list, {}),
#      '21315': defaultdict(list, {}),
#      '21316': defaultdict(list, {}),
#      '21317': defaultdict(list, {}),
#      '21318': defaultdict(list, {}),
#      '23109': defaultdict(list, {}),
#      '23337': defaultdict(list, {}),
#      '23367': defaultdict(list, {})},
#     '_index': 1474}],
#   ["boss'",
#    {'text': {'2728': defaultdict(list, {}), '13560': defaultdict(list, {})},
#     '_index': 1684}],
#   ['boston',
#    {'text': {'916': defaultdict(list, {}),
#      '3207': defaultdict(list, {}),
#      '3208': defaultdict(list, {}),
#      '3209': defaultdict(list, {}),
#      '3756': defaultdict(list, {}),
#      '3766': defaultdict(list, {}),
#      '4247': defaultdict(list, {}),
#      '7755': defaultdict(list, {}),
#      '7799': defaultdict(list, {}),
#      '8058': defaultdict(list, {}),
#      '9254': defaultdict(list, {}),
#      '9255': defaultdict(list, {}),
#      '9256': defaultdict(list, {}),
#      '9257': defaultdict(list, {}),
#      '9258': defaultdict(list, {}),
#      '9297': defaultdict(list, {}),
#      '10879': defaultdict(list, {}),
#      '14443': defaultdict(list, {}),
#      '17006': defaultdict(list, {}),
#      '17038': defaultdict(list, {}),
#      '18610': defaultdict(list, {}),
#      '18611': defaultdict(list, {}),
#      '18612': defaultdict(list, {}),
#      '18613': defaultdict(list, {}),
#      '18629': defaultdict(list, {}),
#      '18630': defaultdict(list, {}),
#      '18631': defaultdict(list, {}),
#      '18632': defaultdict(list, {}),
#      '18633': defaultdict(list, {}),
#      '19422': defaultdict(list, {}),
#      '21115': defaultdict(list, {}),
#      '21116': defaultdict(list, {}),
#      '21117': defaultdict(list, {}),
#      '21118': defaultdict(list, {}),
#      '21119': defaultdict(list, {}),
#      '23023': defaultdict(list, {}),
#      '23024': defaultdict(list, {}),
#      '23025': defaultdict(list, {}),
#      '23026': defaultdict(list, {})},
#     '_index': 805}],
#   ['bot',
#    {'text': {'3996': defaultdict(list, {}),
#      '3997': defaultdict(list, {}),
#      '3998': defaultdict(list, {}),
#      '3999': defaultdict(list, {}),
#      '4004': defaultdict(list, {}),
#      '17807': defaultdict(list, {}),
#      '17808': defaultdict(list, {}),
#      '17809': defaultdict(list, {}),
#      '17810': defaultdict(list, {}),
#      '17813': defaultdict(list, {}),
#      '17816': defaultdict(list, {}),
#      '17819': defaultdict(list, {}),
#      '17824': defaultdict(list, {}),
#      '17825': defaultdict(list, {}),
#      '17826': defaultdict(list, {}),
#      '17828': defaultdict(list, {}),
#      '17841': defaultdict(list, {}),
#      '17865': defaultdict(list, {}),
#      '17866': defaultdict(list, {}),
#      '17868': defaultdict(list, {}),
#      '17869': defaultdict(list, {}),
#      '17870': defaultdict(list, {}),
#      '17882': defaultdict(list, {}),
#      '17883': defaultdict(list, {}),
#      '17892': defaultdict(list, {}),
#      '22172': defaultdict(list, {}),
#      '22173': defaultdict(list, {}),
#      '22174': defaultdict(list, {}),
#      '22175': defaultdict(list, {}),
#      '22177': defaultdict(list, {})},
#     '_index': 2113}],
#   ['both',
#    {'text': {'664': defaultdict(list, {}),
#      '6707': defaultdict(list, {}),
#      '6730': defaultdict(list, {}),
#      '6737': defaultdict(list, {}),
#      '6738': defaultdict(list, {}),
#      '20962': defaultdict(list, {}),
#      '23682': defaultdict(list, {})},
#     '_index': 606}],
#   ['bother', {'text': {'23306': defaultdict(list, {})}, '_index': 5807}],
#   ['bottl',
#    {'text': {'22862': defaultdict(list, {}),
#      '22863': defaultdict(list, {}),
#      '22864': defaultdict(list, {}),
#      '22865': defaultdict(list, {}),
#      '23355': defaultdict(list, {})},
#     '_index': 5487}],
#   ['bottleneck', {'text': {'13834': defaultdict(list, {})}, '_index': 3951}],
#   ['bought',
#    {'text': {'1147': defaultdict(list, {}),
#      '1765': defaultdict(list, {}),
#      '13128': defaultdict(list, {}),
#      '13130': defaultdict(list, {}),
#      '13143': defaultdict(list, {}),
#      '23327': defaultdict(list, {})},
#     '_index': 938}],
#   ['boulder', {'text': {'23660': defaultdict(list, {})}, '_index': 6025}],
#   ['bounc', {'text': {'5499': defaultdict(list, {})}, '_index': 2515}],
#   ['bounti', {'text': {'4889': defaultdict(list, {})}, '_index': 2415}],
#   ['bouquet', {'text': {'23421': defaultdict(list, {})}, '_index': 5886}],
#   ['bourgeoi', {'text': {'3517': defaultdict(list, {})}, '_index': 1951}],
#   ['bowel', {'text': {'21076': defaultdict(list, {})}, '_index': 5088}],
#   ['bowi',
#    {'text': {'12067': defaultdict(list, {}), '18264': defaultdict(list, {})},
#     '_index': 3674}],
#   ['bowl',
#    {'text': {'1707': defaultdict(list, {}),
#      '4590': defaultdict(list, {}),
#      '10076': defaultdict(list, {}),
#      '12336': defaultdict(list, {}),
#      '12346': defaultdict(list, {}),
#      '12347': defaultdict(list, {}),
#      '21831': defaultdict(list, {}),
#      '23526': defaultdict(list, {})},
#     '_index': 1179}],
#   ['box',
#    {'text': {'10089': defaultdict(list, {}),
#      '10090': defaultdict(list, {}),
#      '13467': defaultdict(list, {}),
#      '13468': defaultdict(list, {}),
#      '13470': defaultdict(list, {}),
#      '17654': defaultdict(list, {}),
#      '18127': defaultdict(list, {}),
#      '21340': defaultdict(list, {}),
#      '22749': defaultdict(list, {}),
#      '22993': defaultdict(list, {}),
#      '22994': defaultdict(list, {}),
#      '22995': defaultdict(list, {})},
#     '_index': 3300}],
#   ['boyfriend', {'text': {'17450': defaultdict(list, {})}, '_index': 4518}],
#   ['bracket', {'text': {'21685': defaultdict(list, {})}, '_index': 5163}],
#   ['brad',
#    {'text': {'6305': defaultdict(list, {}),
#      '6306': defaultdict(list, {}),
#      '6307': defaultdict(list, {}),
#      '6308': defaultdict(list, {}),
#      '6309': defaultdict(list, {}),
#      '17401': defaultdict(list, {}),
#      '18202': defaultdict(list, {})},
#     '_index': 2646}],
#   ['bradi', {'text': {'17476': defaultdict(list, {})}, '_index': 4528}],
#   ['bradlei', {'text': {'18467': defaultdict(list, {})}, '_index': 4724}],
#   ['brain', {'text': {'18895': defaultdict(list, {})}, '_index': 4771}],
#   ['brake', {'text': {'23376': defaultdict(list, {})}, '_index': 5845}],
#   ['brambl', {'text': {'19216': defaultdict(list, {})}, '_index': 4835}],
#   ['brand',
#    {'text': {'4724': defaultdict(list, {}),
#      '7365': defaultdict(list, {}),
#      '7427': defaultdict(list, {}),
#      '7460': defaultdict(list, {}),
#      '8655': defaultdict(list, {}),
#      '16465': defaultdict(list, {}),
#      '22862': defaultdict(list, {}),
#      '23212': defaultdict(list, {}),
#      '23250': defaultdict(list, {}),
#      '23687': defaultdict(list, {})},
#     '_index': 2354}],
#   ['brandon', {'text': {'6353': defaultdict(list, {})}, '_index': 2662}],
#   ['brasilia', {'text': {'7739': defaultdict(list, {})}, '_index': 3004}],
#   ['brasseri', {'text': {'2421': defaultdict(list, {})}, '_index': 1595}],
#   ['brazil',
#    {'text': {'1898': defaultdict(list, {}),
#      '1904': defaultdict(list, {}),
#      '3404': defaultdict(list, {}),
#      '4588': defaultdict(list, {}),
#      '4599': defaultdict(list, {}),
#      '5264': defaultdict(list, {}),
#      '5276': defaultdict(list, {}),
#      '7753': defaultdict(list, {}),
#      '10868': defaultdict(list, {}),
#      '10869': defaultdict(list, {}),
#      '10870': defaultdict(list, {}),
#      '10871': defaultdict(list, {}),
#      '10872': defaultdict(list, {}),
#      '14413': defaultdict(list, {}),
#      '15810': defaultdict(list, {}),
#      '15854': defaultdict(list, {}),
#      '19645': defaultdict(list, {}),
#      '19654': defaultdict(list, {}),
#      '19658': defaultdict(list, {}),
#      '21208': defaultdict(list, {}),
#      '21766': defaultdict(list, {}),
#      '21783': defaultdict(list, {}),
#      '21786': defaultdict(list, {}),
#      '21792': defaultdict(list, {})},
#     '_index': 1313}],
#   ['brazilian', {'text': {'21355': defaultdict(list, {})}, '_index': 5122}],
#   ['breach', {'text': {'23668': defaultdict(list, {})}, '_index': 6032}],
#   ['bread',
#    {'text': {'603': defaultdict(list, {}),
#      '2030': defaultdict(list, {}),
#      '2073': defaultdict(list, {}),
#      '4338': defaultdict(list, {}),
#      '4508': defaultdict(list, {}),
#      '6513': defaultdict(list, {}),
#      '6525': defaultdict(list, {}),
#      '6526': defaultdict(list, {}),
#      '6527': defaultdict(list, {}),
#      '6528': defaultdict(list, {}),
#      '6529': defaultdict(list, {}),
#      '6541': defaultdict(list, {}),
#      '6542': defaultdict(list, {}),
#      '6546': defaultdict(list, {}),
#      '6547': defaultdict(list, {}),
#      '6548': defaultdict(list, {}),
#      '10038': defaultdict(list, {}),
#      '11210': defaultdict(list, {}),
#      '11277': defaultdict(list, {}),
#      '11278': defaultdict(list, {}),
#      '11399': defaultdict(list, {}),
#      '11634': defaultdict(list, {}),
#      '11654': defaultdict(list, {}),
#      '11692': defaultdict(list, {}),
#      '17106': defaultdict(list, {}),
#      '18997': defaultdict(list, {}),
#      '19904': defaultdict(list, {}),
#      '21549': defaultdict(list, {}),
#      '22420': defaultdict(list, {}),
#      '22421': defaultdict(list, {}),
#      '22422': defaultdict(list, {}),
#      '22423': defaultdict(list, {}),
#      '22424': defaultdict(list, {})},
#     '_index': 566}],
#   ['break',
#    {'text': {'4811': defaultdict(list, {}),
#      '21277': defaultdict(list, {}),
#      '22521': defaultdict(list, {}),
#      '22898': defaultdict(list, {}),
#      '23636': defaultdict(list, {})},
#     '_index': 2366}],
#   ['breakdown', {'text': {'23485': defaultdict(list, {})}, '_index': 5934}],
#   ['breakfast',
#    {'text': {'2772': defaultdict(list, {}),
#      '12364': defaultdict(list, {}),
#      '14737': defaultdict(list, {}),
#      '14773': defaultdict(list, {})},
#     '_index': 1706}],
#   ...],
#  'pipeline': ['stemmer']}

# %% [markdown]
# This is useful for storing and loading the search index on disk.

# %%
import json
from lunr.index import Index

serialized = index.serialize()

# Save the index
with open('idx.json', 'w') as fd:
    json.dump(serialized, fd)

# Load it again
with open("idx.json") as fd:
    reloaded = json.loads(fd.read())

idx = Index.load(reloaded)
idx.search("plant")
# Out:
# [{'ref': '11998', 'score': 9.056, 'match_data': <MatchData "plant">},
#  {'ref': '9435', 'score': 8.144, 'match_data': <MatchData "plant">},
#  {'ref': '2097', 'score': 7.399, 'match_data': <MatchData "plant">},
#  {'ref': '9433', 'score': 7.399, 'match_data': <MatchData "plant">},
#  {'ref': '23246', 'score': 7.399, 'match_data': <MatchData "plant">},
#  {'ref': '9439', 'score': 6.778, 'match_data': <MatchData "plant">},
#  {'ref': '19441', 'score': 6.254, 'match_data': <MatchData "plant">}]

# %% [markdown]
# lunr.py is great as a search engine for small datasets and rapid prototyping e.g., searching through small texts.
# Benchmarks below to show it performs in retrieving data vs. list comprehension and pandas.

# %%
# %timeit df.loc[lambda d: d['text'].str.contains("spanish")]

# %timeit [d for d in documents if 'spanish' in d['text']]

# %timeit index.search('spanish')

# %timeit [documents[int(i['ref'])] for i in index.search('spanish')]
# Out:
# 10.4 ms ± 487 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.1 ms ± 60.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 389 µs ± 17.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 392 µs ± 18.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
